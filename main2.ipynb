# %%
import os
from openai import AzureOpenAI
from dotenv import load_dotenv
from src.sys_prompt import mc_prompt_emotion_v2, mc_prompt_commitment_v2, mc_prompt_purpose_v2, mc_prompt_how_to_raise_funds_v1
from src.data_processing import get_data
import re
import json
import pandas as pd
import logging
import datetime

# Set file names

# Path of the processed file
file_to_save_processed = r'/Users/harshgarg/Desktop/mc-lm-genai/data/LM Applications 20250624_processed.xlsx'
# Path of the unprocessed file
file_to_import_unprocessed = r"/Users/harshgarg/Desktop/mc-lm-genai/data/LM Applications 20250624.xlsx"
# Path of partially processed file
# file_to_import_partiallyProcessed = r"/Users/harshgarg/Desktop/mc-lm-genai/data/LM Applications 20250502.xlsx"
# Path of the file to run a single row from
# file_to_import_single_cell = r"/Users/harshgarg/Desktop/mc-lm-genai/data/LM Applications 20250502.xlsx"

# %%
# To generate IDs (to better query logs; irrelevant otherwise)

df = get_data(path=file_to_import_unprocessed)
df.to_excel(file_to_import_unprocessed, index=False)

# %% [markdown]
# ## Always run the below cell

# %%
# Configure logging with timestamp
log_filename = f"mc_scoring_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    # handlers=[
    #     logging.FileHandler(log_filename),
    #     logging.StreamHandler()
    # ]
    filename=log_filename,
    force=True
)

# Log the start of the script
logging.info("Script execution started")


load_dotenv()
endpoint = os.getenv("ENDPOINT_URL")
deployment = os.getenv("DEPLOYMENT_NAME_1")
endpoint = os.getenv("ENDPOINT_URL")
subscription_key = os.getenv("AZURE_OPEN_AI_API_KEY")

# Initialize Azure OpenAI Service client with key-based authentication
client = AzureOpenAI(
    azure_endpoint=endpoint,
    api_key=subscription_key,
    api_version="2024-05-01-preview",
)

df = get_data(path=file_to_import_unprocessed)

df['emotion'] = 0
df['purpose'] = 0
df['commitment'] = 0
df['fundraising'] = 0

# %% [markdown]
# ## Helper functions (the next 2 cells)

# %%
def get_llm_output(prompt, row_data):
    # Log the start of the function call
    logging.info(f"Processing row data using prompt: {prompt[:50]}...")
    logging.info(f"Processing row: {row_data}")
    
    try:
        # Prepare the chat prompt
        chat_prompt = [{"role": "user", "content": [{"type": "text", "text": prompt + "\n" + str(row_data)}]}]
        messages = chat_prompt

        # Generate the completion
        logging.info("Sending request to OpenAI API")
        completion = client.chat.completions.create(
            model=deployment,
            messages=messages,
            max_tokens=800,
            temperature=0.7,
            top_p=0.95,
            frequency_penalty=0,
            presence_penalty=0,
            stop=None,
            stream=False,
        )

        # Parse the JSON content from the completion
        response_content = completion.choices[0].message.content
        logging.info("Received response")
        logging.info(f"Response: {response_content}")

        
        # Extract the JSON part from the markdown code block
        json_match = re.search(r'```(?:json)?\s*(.*?)\s*```', response_content, re.DOTALL)
        
        if json_match:
            json_str = json_match.group(1)
            result = json.loads(json_str)
            logging.info("Successfully parsed JSON response")
        else:
            # Fallback if regex doesn't match
            # Try to evaluate directly (be cautious with eval)
            logging.warning("JSON regex match failed, attempting direct eval")
            result = eval(response_content)
            
        return result
    
    except Exception as e:
        # Log any exceptions that occur
        logging.error(f"Error processing: {str(e)}")
        # Return a default value in case of error
        return {"error": str(e), "score": 0}

# %%
def process_row(row_data, value, index):
    # Process fundraising scoring
    if pd.notna(row_data['spon_pledge_how_to_reach_target']) and len(str(row_data['spon_pledge_how_to_reach_target'])) > 0:
        logging.info(f"Processing fundraising for ID: {value['id']}")
        fundraising_result = get_llm_output(mc_prompt_how_to_raise_funds_v1, {'spon_pledge_how_to_reach_target': row_data['spon_pledge_how_to_reach_target']})
        logging.info(f"Fundraising score for ID {value['id']}: {fundraising_result.get('fundraising_score', 0)}")
    else:
        logging.info(f"No fundraising data for ID: {value['id']}, assigning default score 0")
        fundraising_result = {"fundraising_score": 0}


    # Process reason to run data for emotion, purpose and commitment scoring
    if pd.notna(row_data['why_run_for_marie_curie']) and len(str(row_data['why_run_for_marie_curie'])) > 0:
        logging.info(f"Processing emotional content for ID: {value['id']}")
        emotion_result = get_llm_output(mc_prompt_emotion_v2, {"reason": row_data['reason_free_text'] + row_data['reason_drop_down'] + row_data['why_run_for_marie_curie']})
        logging.info(f"Emotion score for ID {value['id']}: {emotion_result.get('emotion', 0)}")
        
        logging.info(f"Processing purpose content for ID: {value['id']}")
        purpose_result = get_llm_output(mc_prompt_purpose_v2, {"reason": row_data['reason_free_text'] + row_data['reason_drop_down'] + row_data['why_run_for_marie_curie']})
        logging.info(f"Purpose score for ID {value['id']}: {purpose_result.get('purpose', 0)}")
        
        logging.info(f"Processing commitment content for ID: {value['id']}")
        commitment_result = get_llm_output(mc_prompt_commitment_v2, {"reason": row_data['reason_free_text'] + row_data['reason_drop_down'] + row_data['why_run_for_marie_curie']})
        logging.info(f"Commitment score for ID {value['id']}: {commitment_result.get('commitment', commitment_result.get('committment', 0))}")
    else:
        logging.info(f"No reason_free_text data for ID: {value['id']}, assigning default scores 0")
        emotion_result = {"emotion": 0}
        purpose_result = {"purpose": 0}
        commitment_result = {"commitment": 0}

    # Update the dataframe with scores
    try:
        df.at[index, 'fundraising'] = fundraising_result['fundraising_score']
        df.at[index, 'emotion'] = emotion_result['emotion']
        df.at[index, 'purpose'] = purpose_result['purpose']
        
        # Handle the commitment/committment spelling variation in the result
        if 'commitment' in commitment_result:
            df.at[index, 'commitment'] = commitment_result['commitment']
        elif 'committment' in commitment_result:
            df.at[index, 'commitment'] = commitment_result['committment']
        else:
            df.at[index, 'commitment'] = 0
            logging.warning(f"No commitment score found for ID {value['id']}")
            
        # Calculate final score
        df.at[index, 'Final_score'] = 0  # Reset the score before adding components
        
        # Add scores from LLM evaluations
        df.at[index, 'Final_score'] += float(df.at[index, 'emotion']) + float(df.at[index, 'purpose']) + float(df.at[index, 'commitment']) + float(df.at[index, 'fundraising'])
        logging.info(f"Base scores sum for ID {value['id']}: {df.at[index, 'Final_score']}")
        
# Score for In Memory
        if value['in_mem'].startswith("Y"):
            df.at[index, 'Final_score'] += 1
            logging.info(f"Added 1 point for in_mem (Y) for ID {value['id']}")
        elif value['in_mem'].startswith("N"):
            df.at[index, 'Final_score'] += 0
            logging.info(f"Added 0 points for in_mem (N) for ID {value['id']}")
        else:
            df.at[index, 'Final_score'] += 0.5
            logging.info(f"Added 0.5 points for in_mem (Other) for ID {value['id']}")

        # Score for In Memory Details - in_memory_drop_down and in_memory_free_text (Currently just checking if they are populated)
        if pd.notna(row_data['in_memory_drop_down']) and len(str(row_data['in_memory_drop_down'])) > 0:
            df.at[index, 'Final_score'] += 1
            logging.info(f"Added 1 point for in_memory_drop_down (Y) for ID {value['id']}")
        else:
            df.at[index, 'Final_score'] += 0
            logging.info(f"Added 0 points for in_memory_drop_down (Blank) for ID {value['id']}")

        if pd.notna(row_data['in_memory_free_text']) and len(str(row_data['in_memory_free_text'])) > 0:
            df.at[index, 'Final_score'] += 1
            logging.info(f"Added 1 point for in_memory_free_text (Y) for ID {value['id']}")
        else:
            df.at[index, 'Final_score'] += 0
            logging.info(f"Added 0 points for in_memory_free_text (Blank) for ID {value['id']}")
        

        # Score for run before
        if value['run_LM_before'].__contains__("No"):
            df.at[index, 'Final_score'] += 0
            logging.info(f"Added 0 point for run_LM_before (No) for ID {value['id']}")
        else:
            df.at[index, 'Final_score'] += 1
            logging.info(f"Added 1 points for run_LM_before (Yes) for ID {value['id']}")

        # Score for sponsor pledge
        if value['spon_pledge_amount'] == "£0 - £2,4999":
            df.at[index, 'Final_score'] += 1
            logging.info(f"Added 1 point for sponsor pledge amount for {value['id']}: {value['spon_pledge_amount']}")
        elif value['spon_pledge_amount'] == "2500":
            df.at[index, 'Final_score'] += 2
            logging.info(f"Added 2 points for sponsor pledge amount for {value['id']}: {value['spon_pledge_amount']}")
        elif value['spon_pledge_amount'] == "£2,500 - £3,499":
            df.at[index, 'Final_score'] += 3
            logging.info(f"Added 3 points for sponsor pledge amount for {value['id']}: {value['spon_pledge_amount']}")
        elif value['spon_pledge_amount'] == "£3,500 - £3,999":
            df.at[index, 'Final_score'] += 4
            logging.info(f"Added 4 points for sponsor pledge amount for {value['id']}: {value['spon_pledge_amount']}")
        elif value['spon_pledge_amount'] == "£4,000 +":
            df.at[index, 'Final_score'] += 5
            logging.info(f"Added 5 points for sponsor pledge amount for {value['id']}: {value['spon_pledge_amount']}")
        else:
            df.at[index, 'Final_score'] += 0
            logging.info(f"Added 0 point for sponsor pledge amount for {value['id']}: Blank")

        # Score for Matched Fundraising
        if value['employee_details_matched_fundraising'].endswith("Yes"):
            df.at[index, 'Final_score'] += 1
            logging.info(f"Added 1 point for employee_details_matched_fundraising (Yes) for ID {value['id']}")
        elif value['employee_details_matched_fundraising'].endswith("No"):
            df.at[index, 'Final_score'] += 0
            logging.info(f"Added 0 points for employee_details_matched_fundraising (No) for ID {value['id']}")
        else:
            df.at[index, 'Final_score'] += 0.5
            logging.info(f"Added 0.5 points for employee_details_matched_fundraising (Unsure) for ID {value['id']}")
        
        # Score for PR_and_media_special_plans
        if value['special_plans_and/or_fancy_dress_drop_down'].startswith("No"):
            df.at[index, 'Final_score'] += 0
            logging.info(f"Added 0 point for special_plans_and/or_fancy_dress_drop_down (No) for ID {value['id']}")
        else:
            df.at[index, 'Final_score'] += 1
            logging.info(f"Added 1 points for special_plans_and/or_fancy_dress_drop_down (Some plan) for ID {value['id']}")
        
        
        # # Score for Public Ballot
        # if value['entered_public_ballot'].endswith("Yes"):
        #     df.at[index, 'Final_score'] += 0
        #     logging.info(f"Added 1 point for entered_public_ballot (Yes) for ID {value['id']}")
        # elif value['entered_public_ballot'].endswith("No"):
        #     df.at[index, 'Final_score'] += 1
        #     logging.info(f"Added 0 points for entered_public_ballot (No) for ID {value['id']}")
        # else:
        #     df.at[index, 'Final_score'] += 0.5
        #     logging.info(f"Added 0.5 points for entered_public_ballot (Other) for ID {value['id']}")
        
        # Score for Pledge Amount (normalized)
        # pledge_score = df.at[index, 'Pledge Amount']/max_amount if pd.notna(df.at[index, 'Pledge Amount']) else 0
        # df.at[index, 'Final_score'] += pledge_score
        # logging.info(f"Added {pledge_score:.4f} points for Pledge Amount for ID {value['id']}")
        
        # logging.info(f"Final score for ID {value['id']}: {df.at[index, 'Final_score']}")
        
    except Exception as e:
        logging.error(f"Error updating scores for ID {value['id']}: {str(e)}")
    
    # Log progress every 10 applications
    if index % 10 == 0 and index > 0:
        logging.info(f"Progress: {index}/{len(df)} applications processed ({index/len(df)*100:.1f}%)")

# %% [markdown]
# ## Process a fresh (unprocessed file)

# %%
# Import data
df = get_data(path=file_to_import_unprocessed)
df = df.fillna("")

logging.info(f"Processing {len(df) if 'df' in locals() else 0} applications")

df["emotion"] = ""
df["purpose"] = ""
df["commitment"] = ""
df["fundraising"] = ""
df['Final_score'] = 0

# Pledge amount is a range in this sheet; need to incorporate processing of this
# max_amount = max(df['Pledge Amount'])

# No matched fundraising in this sheet?
# df['Matched Fundraising'] = df['Matched Fundraising'].fillna("No")
df['in_mem'] = df['in_mem'].fillna("N")
df['entered_public_ballot'] = df['entered_public_ballot'].fillna("No")

for index, value in df.iterrows():
    logging.info(f"Processing application {index+1}/{len(df)}, ID: {value['id']}")
    
    row_data = value.to_dict()
    process_row(row_data, value, index)

    # adding 2 to index to indicate the row number in excel
    print(f"Row {index + 2} processed.")

# Save to excel

df.to_excel(file_to_save_processed, index=False)
# Out:
# /var/folders/90/vqz6m1bx3hb3j40plckgml5w0000gn/T/ipykernel_55515/2882827975.py:116: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, 'Final_score'] += 0.5
# Row 2 processed.
# Row 3 processed.
# Row 4 processed.
# Row 5 processed.
# Row 6 processed.
# Row 7 processed.
# Row 8 processed.
# Row 9 processed.
# Row 10 processed.
# Row 11 processed.
# Row 12 processed.
# Row 13 processed.
# Row 14 processed.
# Row 15 processed.
# Row 16 processed.
# Row 17 processed.
# Row 18 processed.
# Row 19 processed.
# Row 20 processed.
# Row 21 processed.
# Row 22 processed.
# Row 23 processed.
# Row 24 processed.
# Row 25 processed.
# Row 26 processed.
# Row 27 processed.
# Row 28 processed.
# Row 29 processed.
# Row 30 processed.
# Row 31 processed.
# Row 32 processed.
# Row 33 processed.
# Row 34 processed.
# Row 35 processed.
# Row 36 processed.
# Row 37 processed.
# Row 38 processed.
# Row 39 processed.
# Row 40 processed.
# Row 41 processed.
# Row 42 processed.
# Row 43 processed.
# Row 44 processed.
# Row 45 processed.
# Row 46 processed.
# Row 47 processed.
# Row 48 processed.
# Row 49 processed.
# Row 50 processed.
# Row 51 processed.
# Row 52 processed.
# Row 53 processed.
# Row 54 processed.
# Row 55 processed.
# Row 56 processed.
# Row 57 processed.
# Row 58 processed.
# Row 59 processed.
# Row 60 processed.
# Row 61 processed.
# Row 62 processed.
# Row 63 processed.
# Row 64 processed.
# Row 65 processed.
# Row 66 processed.
# Row 67 processed.
# Row 68 processed.
# Row 69 processed.
# Row 70 processed.
# Row 71 processed.
# Row 72 processed.
# Row 73 processed.
# Row 74 processed.
# Row 75 processed.
# Row 76 processed.
# Row 77 processed.
# Row 78 processed.
# Row 79 processed.
# Row 80 processed.
# Row 81 processed.
# Row 82 processed.
# Row 83 processed.
# Row 84 processed.
# Row 85 processed.
# Row 86 processed.
# Row 87 processed.
# Row 88 processed.
# Row 89 processed.
# Row 90 processed.
# Row 91 processed.
# Row 92 processed.
# Row 93 processed.
# Row 94 processed.
# Row 95 processed.
# Row 96 processed.
# Row 97 processed.
# Row 98 processed.
# Row 99 processed.
# Row 100 processed.
# Row 101 processed.
# Row 102 processed.
# Row 103 processed.
# Row 104 processed.
# Row 105 processed.
# Row 106 processed.
# Row 107 processed.
# Row 108 processed.
# Row 109 processed.
# Row 110 processed.
# Row 111 processed.
# Row 112 processed.
# Row 113 processed.
# Row 114 processed.
# Row 115 processed.
# Row 116 processed.
# Row 117 processed.
# Row 118 processed.
# Row 119 processed.
# Row 120 processed.
# Row 121 processed.
# Row 122 processed.
# Row 123 processed.
# Row 124 processed.
# Row 125 processed.
# Row 126 processed.
# Row 127 processed.
# Row 128 processed.
# Row 129 processed.
# Row 130 processed.
# Row 131 processed.
# Row 132 processed.
# Row 133 processed.
# Row 134 processed.
# Row 135 processed.
# Row 136 processed.
# Row 137 processed.
# Row 138 processed.
# Row 139 processed.
# Row 140 processed.
# Row 141 processed.
# Row 142 processed.
# Row 143 processed.
# Row 144 processed.
# Row 145 processed.
# Row 146 processed.
# Row 147 processed.
# Row 148 processed.
# Row 149 processed.
# Row 150 processed.
# Row 151 processed.
# Row 152 processed.
# Row 153 processed.
# Row 154 processed.
# Row 155 processed.
# Row 156 processed.
# Row 157 processed.
# Row 158 processed.
# Row 159 processed.
# Row 160 processed.
# Row 161 processed.
# Row 162 processed.
# Row 163 processed.
# Row 164 processed.
# Row 165 processed.
# Row 166 processed.
# Row 167 processed.
# Row 168 processed.
# Row 169 processed.
# Row 170 processed.
# Row 171 processed.
# Row 172 processed.
# Row 173 processed.
# Row 174 processed.
# Row 175 processed.
# Row 176 processed.
# Row 177 processed.
# Row 178 processed.
# Row 179 processed.
# Row 180 processed.
# Row 181 processed.
# Row 182 processed.
# Row 183 processed.
# Row 184 processed.
# Row 185 processed.
# Row 186 processed.
# Row 187 processed.
# Row 188 processed.
# Row 189 processed.
# Row 190 processed.
# Row 191 processed.
# Row 192 processed.
# Row 193 processed.
# Row 194 processed.
# Row 195 processed.
# Row 196 processed.
# Row 197 processed.
# Row 198 processed.
# Row 199 processed.
# Row 200 processed.
# Row 201 processed.
# Row 202 processed.
# Row 203 processed.
# Row 204 processed.
# Row 205 processed.
# Row 206 processed.
# Row 207 processed.
# Row 208 processed.
# Row 209 processed.
# Row 210 processed.
# Row 211 processed.
# Row 212 processed.
# Row 213 processed.
# Row 214 processed.
# Row 215 processed.
# Row 216 processed.
# Row 217 processed.
# Row 218 processed.
# Row 219 processed.
# Row 220 processed.
# Row 221 processed.
# Row 222 processed.
# Row 223 processed.
# Row 224 processed.
# Row 225 processed.
# Row 226 processed.
# Row 227 processed.
# Row 228 processed.
# Row 229 processed.
# Row 230 processed.
# Row 231 processed.
# Row 232 processed.
# Row 233 processed.
# Row 234 processed.
# Row 235 processed.
# Row 236 processed.
# Row 237 processed.
# Row 238 processed.
# Row 239 processed.
# Row 240 processed.
# Row 241 processed.
# Row 242 processed.
# Row 243 processed.
# Row 244 processed.
# Row 245 processed.
# Row 246 processed.
# Row 247 processed.
# Row 248 processed.
# Row 249 processed.
# Row 250 processed.
# Row 251 processed.
# Row 252 processed.
# Row 253 processed.
# Row 254 processed.
# Row 255 processed.
# Row 256 processed.
# Row 257 processed.
# Row 258 processed.
# Row 259 processed.
# Row 260 processed.
# Row 261 processed.
# Row 262 processed.
# Row 263 processed.
# Row 264 processed.
# Row 265 processed.
# Row 266 processed.
# Row 267 processed.
# Row 268 processed.
# Row 269 processed.
# Row 270 processed.
# Row 271 processed.
# Row 272 processed.
# Row 273 processed.
# Row 274 processed.
# Row 275 processed.
# Row 276 processed.
# Row 277 processed.
# Row 278 processed.
# Row 279 processed.
# Row 280 processed.
# Row 281 processed.
# Row 282 processed.
# Row 283 processed.
# Row 284 processed.
# Row 285 processed.
# Row 286 processed.
# Row 287 processed.
# Row 288 processed.
# Row 289 processed.
# Row 290 processed.
# Row 291 processed.
# Row 292 processed.
# Row 293 processed.
# Row 294 processed.
# Row 295 processed.
# Row 296 processed.
# Row 297 processed.
# Row 298 processed.
# Row 299 processed.
# Row 300 processed.
# Row 301 processed.
# Row 302 processed.
# Row 303 processed.
# Row 304 processed.
# Row 305 processed.
# Row 306 processed.
# Row 307 processed.
# Row 308 processed.
# Row 309 processed.
# Row 310 processed.
# Row 311 processed.
# Row 312 processed.
# Row 313 processed.
# Row 314 processed.
# Row 315 processed.
# Row 316 processed.
# Row 317 processed.
# Row 318 processed.
# Row 319 processed.
# Row 320 processed.
# Row 321 processed.
# Row 322 processed.
# Row 323 processed.
# Row 324 processed.
# Row 325 processed.
# Row 326 processed.
# Row 327 processed.
# Row 328 processed.
# Row 329 processed.
# Row 330 processed.
# Row 331 processed.
# Row 332 processed.
# Row 333 processed.
# Row 334 processed.
# Row 335 processed.
# Row 336 processed.
# Row 337 processed.
# Row 338 processed.
# Row 339 processed.
# Row 340 processed.
# Row 341 processed.
# Row 342 processed.
# Row 343 processed.
# Row 344 processed.
# Row 345 processed.
# Row 346 processed.
# Row 347 processed.
# Row 348 processed.
# Row 349 processed.
# Row 350 processed.
# Row 351 processed.
# Row 352 processed.
# Row 353 processed.
# Row 354 processed.
# Row 355 processed.
# Row 356 processed.
# Row 357 processed.
# Row 358 processed.
# Row 359 processed.
# Row 360 processed.
# Row 361 processed.
# Row 362 processed.
# Row 363 processed.
# Row 364 processed.
# Row 365 processed.
# Row 366 processed.
# Row 367 processed.
# Row 368 processed.
# Row 369 processed.
# Row 370 processed.
# Row 371 processed.
# Row 372 processed.
# Row 373 processed.
# Row 374 processed.
# Row 375 processed.
# Row 376 processed.
# Row 377 processed.
# Row 378 processed.
# Row 379 processed.
# Row 380 processed.
# Row 381 processed.
# Row 382 processed.
# Row 383 processed.
# Row 384 processed.
# Row 385 processed.
# Row 386 processed.
# Row 387 processed.
# Row 388 processed.
# Row 389 processed.
# Row 390 processed.
# Row 391 processed.
# Row 392 processed.
# Row 393 processed.
# Row 394 processed.
# Row 395 processed.
# Row 396 processed.
# Row 397 processed.
# Row 398 processed.
# Row 399 processed.
# Row 400 processed.
# Row 401 processed.
# Row 402 processed.
# Row 403 processed.
# Row 404 processed.
# Row 405 processed.
# Row 406 processed.
# Row 407 processed.
# Row 408 processed.
# Row 409 processed.
# Row 410 processed.
# Row 411 processed.
# Row 412 processed.
# Row 413 processed.
# Row 414 processed.
# Row 415 processed.
# Row 416 processed.
# Row 417 processed.
# Row 418 processed.
# Row 419 processed.
# Row 420 processed.
# Row 421 processed.
# Row 422 processed.
# Row 423 processed.
# Row 424 processed.
# Row 425 processed.
# Row 426 processed.
# Row 427 processed.
# Row 428 processed.
# Row 429 processed.
# Row 430 processed.
# Row 431 processed.
# Row 432 processed.
# Row 433 processed.
# Row 434 processed.
# Row 435 processed.
# Row 436 processed.
# Row 437 processed.
# Row 438 processed.
# Row 439 processed.
# Row 440 processed.
# Row 441 processed.
# Row 442 processed.
# Row 443 processed.
# Row 444 processed.
# Row 445 processed.
# Row 446 processed.
# Row 447 processed.
# Row 448 processed.
# Row 449 processed.
# Row 450 processed.
# Row 451 processed.
# Row 452 processed.
# Row 453 processed.
# Row 454 processed.
# Row 455 processed.
# Row 456 processed.
# Row 457 processed.
# Row 458 processed.
# Row 459 processed.
# Row 460 processed.
# Row 461 processed.
# Row 462 processed.
# Row 463 processed.
# Row 464 processed.
# Row 465 processed.
# Row 466 processed.
# Row 467 processed.
# Row 468 processed.
# Row 469 processed.
# Row 470 processed.
# Row 471 processed.
# Row 472 processed.
# Row 473 processed.
# Row 474 processed.
# Row 475 processed.
# Row 476 processed.
# Row 477 processed.
# Row 478 processed.
# Row 479 processed.
# Row 480 processed.
# Row 481 processed.
# Row 482 processed.
# Row 483 processed.
# Row 484 processed.
# Row 485 processed.
# Row 486 processed.
# Row 487 processed.
# Row 488 processed.
# Row 489 processed.
# Row 490 processed.
# Row 491 processed.
# Row 492 processed.
# Row 493 processed.
# Row 494 processed.
# Row 495 processed.
# Row 496 processed.
# Row 497 processed.
# Row 498 processed.
# Row 499 processed.
# Row 500 processed.
# Row 501 processed.
# Row 502 processed.
# Row 503 processed.
# Row 504 processed.
# Row 505 processed.
# Row 506 processed.
# Row 507 processed.
# Row 508 processed.
# Row 509 processed.
# Row 510 processed.
# Row 511 processed.
# Row 512 processed.
# Row 513 processed.
# Row 514 processed.
# Row 515 processed.
# Row 516 processed.
# Row 517 processed.
# Row 518 processed.
# Row 519 processed.
# Row 520 processed.
# Row 521 processed.
# Row 522 processed.
# Row 523 processed.
# Row 524 processed.
# Row 525 processed.
# Row 526 processed.
# Row 527 processed.
# Row 528 processed.
# Row 529 processed.
# Row 530 processed.
# Row 531 processed.
# Row 532 processed.
# Row 533 processed.
# Row 534 processed.
# Row 535 processed.
# Row 536 processed.
# Row 537 processed.
# Row 538 processed.
# Row 539 processed.
# Row 540 processed.
# Row 541 processed.
# Row 542 processed.
# Row 543 processed.
# Row 544 processed.
# Row 545 processed.
# Row 546 processed.
# Row 547 processed.
# Row 548 processed.
# Row 549 processed.
# Row 550 processed.
# Row 551 processed.
# Row 552 processed.
# Row 553 processed.
# Row 554 processed.
# Row 555 processed.
# Row 556 processed.
# Row 557 processed.
# Row 558 processed.
# Row 559 processed.
# Row 560 processed.
# Row 561 processed.
# Row 562 processed.
# Row 563 processed.
# Row 564 processed.
# Row 565 processed.
# Row 566 processed.
# Row 567 processed.
# Row 568 processed.
# Row 569 processed.
# Row 570 processed.
# Row 571 processed.
# Row 572 processed.
# Row 573 processed.
# Row 574 processed.
# Row 575 processed.
# Row 576 processed.
# Row 577 processed.
# Row 578 processed.
# Row 579 processed.
# Row 580 processed.
# Row 581 processed.
# Row 582 processed.
# Row 583 processed.
# Row 584 processed.
# Row 585 processed.
# Row 586 processed.
# Row 587 processed.
# Row 588 processed.
# Row 589 processed.
# Row 590 processed.
# Row 591 processed.
# Row 592 processed.
# Row 593 processed.
# Row 594 processed.
# Row 595 processed.
# Row 596 processed.
# Row 597 processed.
# Row 598 processed.
# Row 599 processed.
# Row 600 processed.
# Row 601 processed.
# Row 602 processed.
# Row 603 processed.
# Row 604 processed.
# Row 605 processed.
# Row 606 processed.
# Row 607 processed.
# Row 608 processed.
# Row 609 processed.
# Row 610 processed.
# Row 611 processed.
# Row 612 processed.
# Row 613 processed.
# Row 614 processed.
# Row 615 processed.
# Row 616 processed.
# Row 617 processed.
# Row 618 processed.
# Row 619 processed.
# Row 620 processed.
# Row 621 processed.
# Row 622 processed.
# Row 623 processed.
# Row 624 processed.
# Row 625 processed.
# Row 626 processed.
# Row 627 processed.
# Row 628 processed.
# Row 629 processed.
# Row 630 processed.
# Row 631 processed.
# Row 632 processed.
# Row 633 processed.
# Row 634 processed.
# Row 635 processed.
# Row 636 processed.
# Row 637 processed.
# Row 638 processed.
# Row 639 processed.
# Row 640 processed.
# Row 641 processed.
# Row 642 processed.
# Row 643 processed.
# Row 644 processed.
# Row 645 processed.
# Row 646 processed.
# Row 647 processed.
# Row 648 processed.
# Row 649 processed.
# Row 650 processed.
# Row 651 processed.
# Row 652 processed.
# Row 653 processed.
# Row 654 processed.
# Row 655 processed.
# Row 656 processed.
# Row 657 processed.
# Row 658 processed.
# Row 659 processed.
# Row 660 processed.
# Row 661 processed.
# Row 662 processed.
# Row 663 processed.
# Row 664 processed.
# Row 665 processed.
# Row 666 processed.
# Row 667 processed.
# Row 668 processed.
# Row 669 processed.
# Row 670 processed.
# Row 671 processed.
# Row 672 processed.
# Row 673 processed.
# Row 674 processed.
# Row 675 processed.
# Row 676 processed.
# Row 677 processed.
# Row 678 processed.
# Row 679 processed.
# Row 680 processed.
# Row 681 processed.
# Row 682 processed.
# Row 683 processed.
# Row 684 processed.
# Row 685 processed.
# Row 686 processed.
# Row 687 processed.
# Row 688 processed.
# Row 689 processed.
# Row 690 processed.
# Row 691 processed.
# Row 692 processed.
# Row 693 processed.
# Row 694 processed.
# Row 695 processed.
# Row 696 processed.
# Row 697 processed.
# Row 698 processed.
# Row 699 processed.
# Row 700 processed.
# Row 701 processed.
# Row 702 processed.
# Row 703 processed.
# Row 704 processed.
# Row 705 processed.
# Row 706 processed.
# Row 707 processed.
# Row 708 processed.
# Row 709 processed.
# Row 710 processed.
# Row 711 processed.
# Row 712 processed.
# Row 713 processed.
# Row 714 processed.
# Row 715 processed.
# Row 716 processed.
# Row 717 processed.
# Row 718 processed.
# Row 719 processed.
# Row 720 processed.
# Row 721 processed.
# Row 722 processed.
# Row 723 processed.
# Row 724 processed.
# Row 725 processed.
# Row 726 processed.
# Row 727 processed.
# Row 728 processed.
# Row 729 processed.
# Row 730 processed.
# Row 731 processed.
# Row 732 processed.
# Row 733 processed.
# Row 734 processed.
# Row 735 processed.
# Row 736 processed.
# Row 737 processed.
# Row 738 processed.
# Row 739 processed.
# Row 740 processed.
# Row 741 processed.
# Row 742 processed.
# Row 743 processed.
# Row 744 processed.
# Row 745 processed.
# Row 746 processed.
# Row 747 processed.
# Row 748 processed.
# Row 749 processed.
# Row 750 processed.
# Row 751 processed.
# Row 752 processed.
# Row 753 processed.
# Row 754 processed.
# Row 755 processed.
# Row 756 processed.
# Row 757 processed.
# Row 758 processed.
# Row 759 processed.
# Row 760 processed.
# Row 761 processed.
# Row 762 processed.
# Row 763 processed.
# Row 764 processed.
# Row 765 processed.
# Row 766 processed.
# Row 767 processed.
# Row 768 processed.
# Row 769 processed.
# Row 770 processed.
# Row 771 processed.
# Row 772 processed.
# Row 773 processed.
# Row 774 processed.
# Row 775 processed.
# Row 776 processed.
# Row 777 processed.
# Row 778 processed.
# Row 779 processed.
# Row 780 processed.
# Row 781 processed.
# Row 782 processed.
# Row 783 processed.
# Row 784 processed.
# Row 785 processed.
# Row 786 processed.
# Row 787 processed.
# Row 788 processed.
# Row 789 processed.
# Row 790 processed.
# Row 791 processed.
# Row 792 processed.
# Row 793 processed.
# Row 794 processed.
# Row 795 processed.
# Row 796 processed.
# Row 797 processed.
# Row 798 processed.
# Row 799 processed.
# Row 800 processed.
# Row 801 processed.
# Row 802 processed.
# Row 803 processed.
# Row 804 processed.
# Row 805 processed.
# Row 806 processed.
# Row 807 processed.
# Row 808 processed.
# Row 809 processed.
# Row 810 processed.
# Row 811 processed.
# Row 812 processed.
# Row 813 processed.
# Row 814 processed.
# Row 815 processed.
# Row 816 processed.
# Row 817 processed.
# Row 818 processed.
# Row 819 processed.
# Row 820 processed.
# Row 821 processed.
# Row 822 processed.
# Row 823 processed.
# Row 824 processed.
# Row 825 processed.
# Row 826 processed.
# Row 827 processed.
# Row 828 processed.
# Row 829 processed.
# Row 830 processed.
# Row 831 processed.
# Row 832 processed.
# Row 833 processed.
# Row 834 processed.
# Row 835 processed.
# Row 836 processed.
# Row 837 processed.
# Row 838 processed.
# Row 839 processed.
# Row 840 processed.
# Row 841 processed.
# Row 842 processed.
# Row 843 processed.
# Row 844 processed.
# Row 845 processed.
# Row 846 processed.
# Row 847 processed.
# Row 848 processed.
# Row 849 processed.
# Row 850 processed.
# Row 851 processed.
# Row 852 processed.
# Row 853 processed.
# Row 854 processed.
# Row 855 processed.
# Row 856 processed.
# Row 857 processed.
# Row 858 processed.
# Row 859 processed.
# Row 860 processed.
# Row 861 processed.
# Row 862 processed.
# Row 863 processed.
# Row 864 processed.
# Row 865 processed.
# Row 866 processed.
# Row 867 processed.
# Row 868 processed.
# Row 869 processed.
# Row 870 processed.
# Row 871 processed.
# Row 872 processed.
# Row 873 processed.
# Row 874 processed.
# Row 875 processed.
# Row 876 processed.
# Row 877 processed.
# Row 878 processed.
# Row 879 processed.
# Row 880 processed.
# Row 881 processed.
# Row 882 processed.
# Row 883 processed.
# Row 884 processed.
# Row 885 processed.
# Row 886 processed.
# Row 887 processed.
# Row 888 processed.
# Row 889 processed.
# Row 890 processed.
# Row 891 processed.
# Row 892 processed.
# Row 893 processed.
# Row 894 processed.
# Row 895 processed.
# Row 896 processed.
# Row 897 processed.
# Row 898 processed.
# Row 899 processed.
# Row 900 processed.
# Row 901 processed.
# Row 902 processed.
# Row 903 processed.
# Row 904 processed.
# Row 905 processed.
# Row 906 processed.
# Row 907 processed.
# Row 908 processed.
# Row 909 processed.
# Row 910 processed.
# Row 911 processed.
# Row 912 processed.
# Row 913 processed.
# Row 914 processed.
# Row 915 processed.
# Row 916 processed.
# Row 917 processed.
# Row 918 processed.
# Row 919 processed.
# Row 920 processed.
# Row 921 processed.
# Row 922 processed.
# Row 923 processed.
# Row 924 processed.
# Row 925 processed.
# Row 926 processed.
# Row 927 processed.
# Row 928 processed.
# Row 929 processed.
# Row 930 processed.
# Row 931 processed.
# Row 932 processed.
# Row 933 processed.
# Row 934 processed.
# Row 935 processed.
# Row 936 processed.
# Row 937 processed.
# Row 938 processed.
# Row 939 processed.
# Row 940 processed.
# Row 941 processed.
# Row 942 processed.
# Row 943 processed.
# Row 944 processed.
# Row 945 processed.
# Row 946 processed.
# Row 947 processed.
# Row 948 processed.
# Row 949 processed.
# Row 950 processed.
# Row 951 processed.
# Row 952 processed.
# Row 953 processed.
# Row 954 processed.
# Row 955 processed.
# Row 956 processed.
# Row 957 processed.
# Row 958 processed.
# Row 959 processed.
# Row 960 processed.
# Row 961 processed.
# Row 962 processed.
# Row 963 processed.
# Row 964 processed.
# Row 965 processed.
# Row 966 processed.
# Row 967 processed.
# Row 968 processed.
# Row 969 processed.
# Row 970 processed.
# Row 971 processed.
# Row 972 processed.
# Row 973 processed.
# Row 974 processed.
# Row 975 processed.
# Row 976 processed.
# Row 977 processed.
# Row 978 processed.
# Row 979 processed.
# Row 980 processed.
# Row 981 processed.
# Row 982 processed.
# Row 983 processed.
# Row 984 processed.
# Row 985 processed.
# Row 986 processed.
# Row 987 processed.
# Row 988 processed.
# Row 989 processed.
# Row 990 processed.
# Row 991 processed.
# Row 992 processed.
# Row 993 processed.
# Row 994 processed.
# Row 995 processed.
# Row 996 processed.
# Row 997 processed.
# Row 998 processed.
# Row 999 processed.
# Row 1000 processed.
# Row 1001 processed.
# Row 1002 processed.
# Row 1003 processed.
# Row 1004 processed.
# Row 1005 processed.
# Row 1006 processed.
# Row 1007 processed.
# Row 1008 processed.
# Row 1009 processed.
# Row 1010 processed.
# Row 1011 processed.
# Row 1012 processed.
# Row 1013 processed.
# Row 1014 processed.
# Row 1015 processed.
# Row 1016 processed.
# Row 1017 processed.
# Row 1018 processed.
# Row 1019 processed.
# Row 1020 processed.
# Row 1021 processed.
# Row 1022 processed.
# Row 1023 processed.
# Row 1024 processed.
# Row 1025 processed.
# Row 1026 processed.
# Row 1027 processed.
# Row 1028 processed.
# Row 1029 processed.
# Row 1030 processed.
# Row 1031 processed.
# Row 1032 processed.
# Row 1033 processed.
# Row 1034 processed.
# Row 1035 processed.
# Row 1036 processed.
# Row 1037 processed.
# Row 1038 processed.
# Row 1039 processed.
# Row 1040 processed.
# Row 1041 processed.
# Row 1042 processed.
# Row 1043 processed.
# Row 1044 processed.
# Row 1045 processed.
# Row 1046 processed.
# Row 1047 processed.
# Row 1048 processed.
# Row 1049 processed.
# Row 1050 processed.
# Row 1051 processed.
# Row 1052 processed.
# Row 1053 processed.
# Row 1054 processed.
# Row 1055 processed.
# Row 1056 processed.
# Row 1057 processed.
# Row 1058 processed.
# Row 1059 processed.
# Row 1060 processed.
# Row 1061 processed.
# Row 1062 processed.
# Row 1063 processed.
# Row 1064 processed.
# Row 1065 processed.
# Row 1066 processed.
# Row 1067 processed.
# Row 1068 processed.
# Row 1069 processed.
# Row 1070 processed.
# Row 1071 processed.
# Row 1072 processed.
# Row 1073 processed.
# Row 1074 processed.
# Row 1075 processed.
# Row 1076 processed.
# Row 1077 processed.
# Row 1078 processed.
# Row 1079 processed.
# Row 1080 processed.
# Row 1081 processed.
# Row 1082 processed.
# Row 1083 processed.
# Row 1084 processed.
# Row 1085 processed.
# Row 1086 processed.
# Row 1087 processed.
# Row 1088 processed.
# Row 1089 processed.
# Row 1090 processed.
# Row 1091 processed.
# Row 1092 processed.
# Row 1093 processed.
# Row 1094 processed.
# Row 1095 processed.
# Row 1096 processed.
# Row 1097 processed.
# Row 1098 processed.
# Row 1099 processed.
# Row 1100 processed.
# Row 1101 processed.
# Row 1102 processed.
# Row 1103 processed.
# Row 1104 processed.
# Row 1105 processed.
# Row 1106 processed.
# Row 1107 processed.
# Row 1108 processed.
# Row 1109 processed.
# Row 1110 processed.
# Row 1111 processed.
# Row 1112 processed.
# Row 1113 processed.
# Row 1114 processed.
# Row 1115 processed.
# Row 1116 processed.
# Row 1117 processed.
# Row 1118 processed.
# Row 1119 processed.
# Row 1120 processed.
# Row 1121 processed.
# Row 1122 processed.
# Row 1123 processed.
# Row 1124 processed.
# Row 1125 processed.
# Row 1126 processed.
# Row 1127 processed.
# Row 1128 processed.
# Row 1129 processed.
# Row 1130 processed.
# Row 1131 processed.
# Row 1132 processed.
# Row 1133 processed.
# Row 1134 processed.
# Row 1135 processed.
# Row 1136 processed.
# Row 1137 processed.
# Row 1138 processed.
# Row 1139 processed.
# Row 1140 processed.
# Row 1141 processed.
# Row 1142 processed.
# Row 1143 processed.
# Row 1144 processed.
# Row 1145 processed.
# Row 1146 processed.
# Row 1147 processed.
# Row 1148 processed.
# Row 1149 processed.
# Row 1150 processed.
# Row 1151 processed.
# Row 1152 processed.
# Row 1153 processed.
# Row 1154 processed.
# Row 1155 processed.
# Row 1156 processed.
# Row 1157 processed.
# Row 1158 processed.
# Row 1159 processed.
# Row 1160 processed.
# Row 1161 processed.
# Row 1162 processed.
# Row 1163 processed.
# Row 1164 processed.
# Row 1165 processed.
# Row 1166 processed.
# Row 1167 processed.
# Row 1168 processed.
# Row 1169 processed.
# Row 1170 processed.
# Row 1171 processed.
# Row 1172 processed.
# Row 1173 processed.
# Row 1174 processed.
# Row 1175 processed.
# Row 1176 processed.
# Row 1177 processed.
# Row 1178 processed.
# Row 1179 processed.
# Row 1180 processed.
# Row 1181 processed.
# Row 1182 processed.
# Row 1183 processed.
# Row 1184 processed.
# Row 1185 processed.
# Row 1186 processed.
# Row 1187 processed.
# Row 1188 processed.
# Row 1189 processed.
# Row 1190 processed.
# Row 1191 processed.
# Row 1192 processed.
# Row 1193 processed.
# Row 1194 processed.
# Row 1195 processed.
# Row 1196 processed.
# Row 1197 processed.
# Row 1198 processed.
# Row 1199 processed.
# Row 1200 processed.
# Row 1201 processed.
# Row 1202 processed.
# Row 1203 processed.
# Row 1204 processed.
# Row 1205 processed.
# Row 1206 processed.
# Row 1207 processed.
# Row 1208 processed.
# Row 1209 processed.
# Row 1210 processed.
# Row 1211 processed.
# Row 1212 processed.
# Row 1213 processed.
# Row 1214 processed.
# Row 1215 processed.
# Row 1216 processed.
# Row 1217 processed.
# Row 1218 processed.
# Row 1219 processed.
# Row 1220 processed.
# Row 1221 processed.
# Row 1222 processed.
# Row 1223 processed.
# Row 1224 processed.
# Row 1225 processed.
# Row 1226 processed.
# Row 1227 processed.
# Row 1228 processed.
# Row 1229 processed.
# Row 1230 processed.
# Row 1231 processed.
# Row 1232 processed.
# Row 1233 processed.
# Row 1234 processed.
# Row 1235 processed.
# Row 1236 processed.
# Row 1237 processed.
# Row 1238 processed.
# Row 1239 processed.
# Row 1240 processed.
# Row 1241 processed.
# Row 1242 processed.
# Row 1243 processed.
# Row 1244 processed.
# Row 1245 processed.
# Row 1246 processed.
# Row 1247 processed.
# Row 1248 processed.
# Row 1249 processed.
# Row 1250 processed.
# Row 1251 processed.
# Row 1252 processed.
# Row 1253 processed.
# Row 1254 processed.
# Row 1255 processed.
# Row 1256 processed.
# Row 1257 processed.
# Row 1258 processed.
# Row 1259 processed.
# Row 1260 processed.
# Row 1261 processed.
# Row 1262 processed.
# Row 1263 processed.
# Row 1264 processed.
# Row 1265 processed.
# Row 1266 processed.
# Row 1267 processed.
# Row 1268 processed.
# Row 1269 processed.
# Row 1270 processed.
# Row 1271 processed.
# Row 1272 processed.
# Row 1273 processed.
# Row 1274 processed.
# Row 1275 processed.
# Row 1276 processed.
# Row 1277 processed.
# Row 1278 processed.
# Row 1279 processed.
# Row 1280 processed.
# Row 1281 processed.
# Row 1282 processed.
# Row 1283 processed.
# Row 1284 processed.
# Row 1285 processed.
# Row 1286 processed.
# Row 1287 processed.
# Row 1288 processed.
# Row 1289 processed.
# Row 1290 processed.
# Row 1291 processed.
# Row 1292 processed.
# Row 1293 processed.
# Row 1294 processed.
# Row 1295 processed.
# Row 1296 processed.
# Row 1297 processed.
# Row 1298 processed.
# Row 1299 processed.
# Row 1300 processed.
# Row 1301 processed.
# Row 1302 processed.
# Row 1303 processed.
# Row 1304 processed.
# Row 1305 processed.
# Row 1306 processed.
# Row 1307 processed.
# Row 1308 processed.
# Row 1309 processed.
# Row 1310 processed.
# Row 1311 processed.
# Row 1312 processed.
# Row 1313 processed.
# Row 1314 processed.
# Row 1315 processed.
# Row 1316 processed.
# Row 1317 processed.
# Row 1318 processed.
# Row 1319 processed.
# Row 1320 processed.
# Row 1321 processed.
# Row 1322 processed.
# Row 1323 processed.
# Row 1324 processed.
# Row 1325 processed.
# Row 1326 processed.
# Row 1327 processed.
# Row 1328 processed.
# Row 1329 processed.
# Row 1330 processed.
# Row 1331 processed.
# Row 1332 processed.
# Row 1333 processed.
# Row 1334 processed.
# Row 1335 processed.
# Row 1336 processed.
# Row 1337 processed.
# Row 1338 processed.
# Row 1339 processed.
# Row 1340 processed.
# Row 1341 processed.
# Row 1342 processed.
# Row 1343 processed.
# Row 1344 processed.
# Row 1345 processed.
# Row 1346 processed.
# Row 1347 processed.
# Row 1348 processed.
# Row 1349 processed.
# Row 1350 processed.
# Row 1351 processed.
# Row 1352 processed.
# Row 1353 processed.
# Row 1354 processed.
# Row 1355 processed.
# Row 1356 processed.
# Row 1357 processed.
# Row 1358 processed.
# Row 1359 processed.
# Row 1360 processed.
# Row 1361 processed.
# Row 1362 processed.
# Row 1363 processed.
# Row 1364 processed.
# Row 1365 processed.
# Row 1366 processed.
# Row 1367 processed.
# Row 1368 processed.
# Row 1369 processed.
# Row 1370 processed.
# Row 1371 processed.
# Row 1372 processed.
# Row 1373 processed.
# Row 1374 processed.
# Row 1375 processed.
# Row 1376 processed.
# Row 1377 processed.
# Row 1378 processed.
# Row 1379 processed.
# Row 1380 processed.
# Row 1381 processed.
# Row 1382 processed.
# Row 1383 processed.
# Row 1384 processed.
# Row 1385 processed.
# Row 1386 processed.
# Row 1387 processed.
# Row 1388 processed.
# Row 1389 processed.
# Row 1390 processed.
# Row 1391 processed.
# Row 1392 processed.
# Row 1393 processed.
# Row 1394 processed.
# Row 1395 processed.
# Row 1396 processed.
# Row 1397 processed.
# Row 1398 processed.
# Row 1399 processed.
# Row 1400 processed.
# Row 1401 processed.
# Row 1402 processed.
# Row 1403 processed.
# Row 1404 processed.
# Row 1405 processed.
# Row 1406 processed.
# Row 1407 processed.
# Row 1408 processed.
# Row 1409 processed.
# Row 1410 processed.
# Row 1411 processed.
# Row 1412 processed.
# Row 1413 processed.
# Row 1414 processed.
# Row 1415 processed.
# Row 1416 processed.
# Row 1417 processed.
# Row 1418 processed.
# Row 1419 processed.
# Row 1420 processed.
# Row 1421 processed.
# Row 1422 processed.
# Row 1423 processed.
# Row 1424 processed.
# Row 1425 processed.
# Row 1426 processed.
# Row 1427 processed.
# Row 1428 processed.
# Row 1429 processed.
# Row 1430 processed.
# Row 1431 processed.
# Row 1432 processed.
# Row 1433 processed.
# Row 1434 processed.
# Row 1435 processed.
# Row 1436 processed.
# Row 1437 processed.
# Row 1438 processed.
# Row 1439 processed.
# Row 1440 processed.
# Row 1441 processed.
# Row 1442 processed.
# Row 1443 processed.
# Row 1444 processed.
# Row 1445 processed.
# Row 1446 processed.
# Row 1447 processed.
# Row 1448 processed.
# Row 1449 processed.
# Row 1450 processed.
# Row 1451 processed.
# Row 1452 processed.
# Row 1453 processed.
# Row 1454 processed.
# Row 1455 processed.
# Row 1456 processed.
# Row 1457 processed.
# Row 1458 processed.
# Row 1459 processed.
# Row 1460 processed.
# Row 1461 processed.
# Row 1462 processed.
# Row 1463 processed.
# Row 1464 processed.
# Row 1465 processed.
# Row 1466 processed.
# Row 1467 processed.
# Row 1468 processed.
# Row 1469 processed.
# Row 1470 processed.
# Row 1471 processed.
# Row 1472 processed.
# Row 1473 processed.
# Row 1474 processed.
# Row 1475 processed.
# Row 1476 processed.
# Row 1477 processed.
# Row 1478 processed.
# Row 1479 processed.
# Row 1480 processed.
# Row 1481 processed.
# Row 1482 processed.
# Row 1483 processed.
# Row 1484 processed.
# Row 1485 processed.
# Row 1486 processed.
# Row 1487 processed.
# Row 1488 processed.
# Row 1489 processed.
# Row 1490 processed.
# Row 1491 processed.
# Row 1492 processed.
# Row 1493 processed.
# Row 1494 processed.
# Row 1495 processed.
# Row 1496 processed.
# Row 1497 processed.
# Row 1498 processed.
# Row 1499 processed.
# Row 1500 processed.
# Row 1501 processed.
# Row 1502 processed.
# Row 1503 processed.
# Row 1504 processed.
# Row 1505 processed.
# Row 1506 processed.
# Row 1507 processed.
# Row 1508 processed.
# Row 1509 processed.
# Row 1510 processed.
# Row 1511 processed.
# Row 1512 processed.
# Row 1513 processed.
# Row 1514 processed.
# Row 1515 processed.
# Row 1516 processed.
# Row 1517 processed.
# Row 1518 processed.
# Row 1519 processed.
# Row 1520 processed.
# Row 1521 processed.
# Row 1522 processed.
# Row 1523 processed.
# Row 1524 processed.
# Row 1525 processed.
# Row 1526 processed.
# Row 1527 processed.
# Row 1528 processed.
# Row 1529 processed.
# Row 1530 processed.
# Row 1531 processed.
# Row 1532 processed.
# Row 1533 processed.
# Row 1534 processed.
# Row 1535 processed.
# Row 1536 processed.
# Row 1537 processed.
# Row 1538 processed.
# Row 1539 processed.
# Row 1540 processed.
# Row 1541 processed.
# Row 1542 processed.
# Row 1543 processed.
# Row 1544 processed.
# Row 1545 processed.
# Row 1546 processed.
# Row 1547 processed.
# Row 1548 processed.
# Row 1549 processed.
# Row 1550 processed.
# Row 1551 processed.
# Row 1552 processed.
# Row 1553 processed.
# Row 1554 processed.
# Row 1555 processed.
# Row 1556 processed.
# Row 1557 processed.
# Row 1558 processed.
# Row 1559 processed.
# Row 1560 processed.
# Row 1561 processed.
# Row 1562 processed.
# Row 1563 processed.
# Row 1564 processed.
# Row 1565 processed.
# Row 1566 processed.
# Row 1567 processed.
# Row 1568 processed.
# Row 1569 processed.
# Row 1570 processed.
# Row 1571 processed.
# Row 1572 processed.
# Row 1573 processed.
# Row 1574 processed.
# Row 1575 processed.
# Row 1576 processed.
# Row 1577 processed.
# Row 1578 processed.
# Row 1579 processed.
# Row 1580 processed.
# Row 1581 processed.
# Row 1582 processed.
# Row 1583 processed.
# Row 1584 processed.
# Row 1585 processed.
# Row 1586 processed.
# Row 1587 processed.
# Row 1588 processed.
# Row 1589 processed.
# Row 1590 processed.
# Row 1591 processed.
# Row 1592 processed.
# Row 1593 processed.
# Row 1594 processed.
# Row 1595 processed.
# Row 1596 processed.
# Row 1597 processed.
# Row 1598 processed.
# Row 1599 processed.
# Row 1600 processed.
# Row 1601 processed.
# Row 1602 processed.
# Row 1603 processed.
# Row 1604 processed.
# Row 1605 processed.
# Row 1606 processed.
# Row 1607 processed.
# Row 1608 processed.
# Row 1609 processed.
# Row 1610 processed.
# Row 1611 processed.
# Row 1612 processed.
# Row 1613 processed.
# Row 1614 processed.
# Row 1615 processed.
# Row 1616 processed.
# Row 1617 processed.
# Row 1618 processed.
# Row 1619 processed.
# Row 1620 processed.
# Row 1621 processed.
# Row 1622 processed.
# Row 1623 processed.
# Row 1624 processed.
# Row 1625 processed.
# Row 1626 processed.
# Row 1627 processed.
# Row 1628 processed.
# Row 1629 processed.
# Row 1630 processed.
# Row 1631 processed.
# Row 1632 processed.
# Row 1633 processed.
# Row 1634 processed.
# Row 1635 processed.
# Row 1636 processed.
# Row 1637 processed.
# Row 1638 processed.
# Row 1639 processed.
# Row 1640 processed.
# Row 1641 processed.
# Row 1642 processed.
# Row 1643 processed.
# Row 1644 processed.
# Row 1645 processed.
# Row 1646 processed.
# Row 1647 processed.
# Row 1648 processed.
# Row 1649 processed.
# Row 1650 processed.
# Row 1651 processed.
# Row 1652 processed.
# Row 1653 processed.
# Row 1654 processed.
# Row 1655 processed.
# Row 1656 processed.
# Row 1657 processed.
# Row 1658 processed.
# Row 1659 processed.
# Row 1660 processed.
# Row 1661 processed.
# Row 1662 processed.
# Row 1663 processed.
# Row 1664 processed.
# Row 1665 processed.
# Row 1666 processed.
# Row 1667 processed.
# Row 1668 processed.
# Row 1669 processed.
# Row 1670 processed.
# Row 1671 processed.
# Row 1672 processed.
# Row 1673 processed.
# Row 1674 processed.
# Row 1675 processed.
# Row 1676 processed.
# Row 1677 processed.
# Row 1678 processed.
# Row 1679 processed.
# Row 1680 processed.
# Row 1681 processed.
# Row 1682 processed.
# Row 1683 processed.
# Row 1684 processed.
# Row 1685 processed.
# Row 1686 processed.
# Row 1687 processed.
# Row 1688 processed.
# Row 1689 processed.
# Row 1690 processed.
# Row 1691 processed.
# Row 1692 processed.
# Row 1693 processed.
# Row 1694 processed.
# Row 1695 processed.
# Row 1696 processed.
# Row 1697 processed.
# Row 1698 processed.
# Row 1699 processed.
# Row 1700 processed.
# Row 1701 processed.
# Row 1702 processed.
# Row 1703 processed.
# Row 1704 processed.
# Row 1705 processed.
# Row 1706 processed.
# Row 1707 processed.
# Row 1708 processed.
# Row 1709 processed.
# Row 1710 processed.
# Row 1711 processed.
# Row 1712 processed.
# Row 1713 processed.
# Row 1714 processed.
# Row 1715 processed.
# Row 1716 processed.
# Row 1717 processed.
# Row 1718 processed.
# Row 1719 processed.
# Row 1720 processed.
# Row 1721 processed.
# Row 1722 processed.
# Row 1723 processed.
# Row 1724 processed.
# Row 1725 processed.
# Row 1726 processed.
# Row 1727 processed.
# Row 1728 processed.
# Row 1729 processed.
# Row 1730 processed.
# Row 1731 processed.
# Row 1732 processed.
# Row 1733 processed.
# Row 1734 processed.
# Row 1735 processed.
# Row 1736 processed.
# Row 1737 processed.
# Row 1738 processed.
# Row 1739 processed.
# Row 1740 processed.
# Row 1741 processed.
# Row 1742 processed.
# Row 1743 processed.
# Row 1744 processed.
# Row 1745 processed.
# Row 1746 processed.
# Row 1747 processed.
# Row 1748 processed.
# Row 1749 processed.
# Row 1750 processed.
# Row 1751 processed.
# Row 1752 processed.
# Row 1753 processed.
# Row 1754 processed.
# Row 1755 processed.
# Row 1756 processed.
# Row 1757 processed.
# Row 1758 processed.
# Row 1759 processed.
# Row 1760 processed.
# Row 1761 processed.
# Row 1762 processed.
# Row 1763 processed.
# Row 1764 processed.
# Row 1765 processed.
# Row 1766 processed.
# Row 1767 processed.
# Row 1768 processed.
# Row 1769 processed.
# Row 1770 processed.
# Row 1771 processed.
# Row 1772 processed.
# Row 1773 processed.
# Row 1774 processed.
# Row 1775 processed.
# Row 1776 processed.
# Row 1777 processed.
# Row 1778 processed.
# Row 1779 processed.
# Row 1780 processed.
# Row 1781 processed.
# Row 1782 processed.
# Row 1783 processed.
# Row 1784 processed.
# Row 1785 processed.
# Row 1786 processed.
# Row 1787 processed.
# Row 1788 processed.
# Row 1789 processed.
# Row 1790 processed.
# Row 1791 processed.
# Row 1792 processed.
# Row 1793 processed.
# Row 1794 processed.
# Row 1795 processed.
# Row 1796 processed.
# Row 1797 processed.
# Row 1798 processed.
# Row 1799 processed.
# Row 1800 processed.
# Row 1801 processed.
# Row 1802 processed.
# Row 1803 processed.
# Row 1804 processed.
# Row 1805 processed.
# Row 1806 processed.
# Row 1807 processed.
# Row 1808 processed.
# Row 1809 processed.
# Row 1810 processed.
# Row 1811 processed.
# Row 1812 processed.
# Row 1813 processed.
# Row 1814 processed.
# Row 1815 processed.
# Row 1816 processed.
# Row 1817 processed.
# Row 1818 processed.
# Row 1819 processed.
# Row 1820 processed.
# Row 1821 processed.
# Row 1822 processed.
# Row 1823 processed.
# Row 1824 processed.
# Row 1825 processed.
# Row 1826 processed.
# Row 1827 processed.
# Row 1828 processed.
# Row 1829 processed.
# Row 1830 processed.
# Row 1831 processed.
# Row 1832 processed.
# Row 1833 processed.
# Row 1834 processed.
# Row 1835 processed.
# Row 1836 processed.
# Row 1837 processed.
# Row 1838 processed.
# Row 1839 processed.
# Row 1840 processed.
# Row 1841 processed.
# Row 1842 processed.
# Row 1843 processed.
# Row 1844 processed.
# Row 1845 processed.
# Row 1846 processed.
# Row 1847 processed.
# Row 1848 processed.
# Row 1849 processed.
# Row 1850 processed.
# Row 1851 processed.
# Row 1852 processed.
# Row 1853 processed.
# Row 1854 processed.
# Row 1855 processed.
# Row 1856 processed.
# Row 1857 processed.
# Row 1858 processed.
# Row 1859 processed.
# Row 1860 processed.
# Row 1861 processed.
# Row 1862 processed.
# Row 1863 processed.
# Row 1864 processed.
# Row 1865 processed.
# Row 1866 processed.
# Row 1867 processed.
# Row 1868 processed.
# Row 1869 processed.
# Row 1870 processed.
# Row 1871 processed.
# Row 1872 processed.
# Row 1873 processed.
# Row 1874 processed.
# Row 1875 processed.
# Row 1876 processed.
# Row 1877 processed.
# Row 1878 processed.
# Row 1879 processed.
# Row 1880 processed.
# Row 1881 processed.
# Row 1882 processed.
# Row 1883 processed.
# Row 1884 processed.
# Row 1885 processed.
# Row 1886 processed.
# Row 1887 processed.
# Row 1888 processed.
# Row 1889 processed.
# Row 1890 processed.
# Row 1891 processed.
# Row 1892 processed.
# Row 1893 processed.
# Row 1894 processed.
# Row 1895 processed.
# Row 1896 processed.
# Row 1897 processed.
# Row 1898 processed.
# Row 1899 processed.
# Row 1900 processed.
# Row 1901 processed.
# Row 1902 processed.
# Row 1903 processed.
# Row 1904 processed.
# Row 1905 processed.
# Row 1906 processed.
# Row 1907 processed.
# Row 1908 processed.
# Row 1909 processed.
# Row 1910 processed.
# Row 1911 processed.
# Row 1912 processed.
# Row 1913 processed.
# Row 1914 processed.
# Row 1915 processed.
# Row 1916 processed.
# Row 1917 processed.
# Row 1918 processed.
# Row 1919 processed.
# Row 1920 processed.
# Row 1921 processed.
# Row 1922 processed.
# Row 1923 processed.
# Row 1924 processed.
# Row 1925 processed.
# Row 1926 processed.
# Row 1927 processed.
# Row 1928 processed.
# Row 1929 processed.
# Row 1930 processed.
# Row 1931 processed.
# Row 1932 processed.
# Row 1933 processed.
# Row 1934 processed.
# Row 1935 processed.
# Row 1936 processed.
# Row 1937 processed.
# Row 1938 processed.
# Row 1939 processed.
# Row 1940 processed.
# Row 1941 processed.
# Row 1942 processed.
# Row 1943 processed.
# Row 1944 processed.
# Row 1945 processed.
# Row 1946 processed.
# Row 1947 processed.
# Row 1948 processed.
# Row 1949 processed.
# Row 1950 processed.
# Row 1951 processed.
# Row 1952 processed.
# Row 1953 processed.
# Row 1954 processed.
# Row 1955 processed.
# Row 1956 processed.
# Row 1957 processed.
# Row 1958 processed.
# Row 1959 processed.
# Row 1960 processed.
# Row 1961 processed.
# Row 1962 processed.
# Row 1963 processed.
# Row 1964 processed.
# Row 1965 processed.
# Row 1966 processed.
# Row 1967 processed.
# Row 1968 processed.
# Row 1969 processed.
# Row 1970 processed.
# Row 1971 processed.
# Row 1972 processed.
# Row 1973 processed.
# Row 1974 processed.
# Row 1975 processed.
# Row 1976 processed.
# Row 1977 processed.
# Row 1978 processed.
# Row 1979 processed.
# Row 1980 processed.
# Row 1981 processed.
# Row 1982 processed.
# Row 1983 processed.
# Row 1984 processed.
# Row 1985 processed.
# Row 1986 processed.
# Row 1987 processed.
# Row 1988 processed.
# Row 1989 processed.
# Row 1990 processed.
# Row 1991 processed.
# Row 1992 processed.
# Row 1993 processed.
# Row 1994 processed.
# Row 1995 processed.
# Row 1996 processed.
# Row 1997 processed.
# Row 1998 processed.
# Row 1999 processed.
# Row 2000 processed.
# Row 2001 processed.
# Row 2002 processed.
# Row 2003 processed.
# Row 2004 processed.
# Row 2005 processed.
# Row 2006 processed.
# Row 2007 processed.
# Row 2008 processed.
# Row 2009 processed.
# Row 2010 processed.
# Row 2011 processed.
# Row 2012 processed.
# Row 2013 processed.
# Row 2014 processed.
# Row 2015 processed.
# Row 2016 processed.
# Row 2017 processed.
# Row 2018 processed.
# Row 2019 processed.
# Row 2020 processed.
# Row 2021 processed.
# Row 2022 processed.
# Row 2023 processed.
# Row 2024 processed.
# Row 2025 processed.
# Row 2026 processed.
# Row 2027 processed.
# Row 2028 processed.
# Row 2029 processed.
# Row 2030 processed.
# Row 2031 processed.
# Row 2032 processed.
# Row 2033 processed.
# Row 2034 processed.
# Row 2035 processed.
# Row 2036 processed.
# Row 2037 processed.
# Row 2038 processed.
# Row 2039 processed.
# Row 2040 processed.
# Row 2041 processed.
# Row 2042 processed.
# Row 2043 processed.
# Row 2044 processed.
# Row 2045 processed.
# Row 2046 processed.
# Row 2047 processed.
# Row 2048 processed.
# Row 2049 processed.
# Row 2050 processed.
# Row 2051 processed.
# Row 2052 processed.
# Row 2053 processed.
# Row 2054 processed.
# Row 2055 processed.
# Row 2056 processed.
# Row 2057 processed.
# Row 2058 processed.
# Row 2059 processed.
# Row 2060 processed.
# Row 2061 processed.
# Row 2062 processed.
# Row 2063 processed.
# Row 2064 processed.
# Row 2065 processed.
# Row 2066 processed.
# Row 2067 processed.
# Row 2068 processed.
# Row 2069 processed.
# Row 2070 processed.
# Row 2071 processed.
# Row 2072 processed.
# Row 2073 processed.
# Row 2074 processed.
# Row 2075 processed.
# Row 2076 processed.
# Row 2077 processed.
# Row 2078 processed.
# Row 2079 processed.
# Row 2080 processed.
# Row 2081 processed.
# Row 2082 processed.
# Row 2083 processed.
# Row 2084 processed.
# Row 2085 processed.
# Row 2086 processed.
# Row 2087 processed.
# Row 2088 processed.
# Row 2089 processed.
# Row 2090 processed.
# Row 2091 processed.
# Row 2092 processed.
# Row 2093 processed.
# Row 2094 processed.
# Row 2095 processed.
# Row 2096 processed.
# Row 2097 processed.
# Row 2098 processed.
# Row 2099 processed.
# Row 2100 processed.
# Row 2101 processed.
# Row 2102 processed.
# Row 2103 processed.
# Row 2104 processed.
# Row 2105 processed.
# Row 2106 processed.
# Row 2107 processed.
# Row 2108 processed.
# Row 2109 processed.
# Row 2110 processed.
# Row 2111 processed.
# Row 2112 processed.
# Row 2113 processed.
# Row 2114 processed.
# Row 2115 processed.
# Row 2116 processed.
# Row 2117 processed.
# Row 2118 processed.
# Row 2119 processed.
# Row 2120 processed.
# Row 2121 processed.
# Row 2122 processed.
# Row 2123 processed.
# Row 2124 processed.
# Row 2125 processed.
# Row 2126 processed.
# Row 2127 processed.
# Row 2128 processed.
# Row 2129 processed.
# Row 2130 processed.
# Row 2131 processed.
# Row 2132 processed.
# Row 2133 processed.
# Row 2134 processed.
# Row 2135 processed.
# Row 2136 processed.
# Row 2137 processed.
# Row 2138 processed.
# Row 2139 processed.
# Row 2140 processed.
# Row 2141 processed.
# Row 2142 processed.
# Row 2143 processed.
# Row 2144 processed.
# Row 2145 processed.
# Row 2146 processed.
# Row 2147 processed.
# Row 2148 processed.
# Row 2149 processed.
# Row 2150 processed.
# Row 2151 processed.
# Row 2152 processed.
# Row 2153 processed.
# Row 2154 processed.
# Row 2155 processed.
# Row 2156 processed.
# Row 2157 processed.
# Row 2158 processed.
# Row 2159 processed.
# Row 2160 processed.
# Row 2161 processed.
# Row 2162 processed.
# Row 2163 processed.
# Row 2164 processed.
# Row 2165 processed.
# Row 2166 processed.
# Row 2167 processed.
# Row 2168 processed.
# Row 2169 processed.
# Row 2170 processed.
# Row 2171 processed.
# Row 2172 processed.
# Row 2173 processed.
# Row 2174 processed.
# Row 2175 processed.
# Row 2176 processed.
# Row 2177 processed.
# Row 2178 processed.
# Row 2179 processed.
# Row 2180 processed.
# Row 2181 processed.
# Row 2182 processed.
# Row 2183 processed.
# Row 2184 processed.
# Row 2185 processed.
# Row 2186 processed.
# Row 2187 processed.
# Row 2188 processed.
# Row 2189 processed.
# Row 2190 processed.
# Row 2191 processed.
# Row 2192 processed.
# Row 2193 processed.
# Row 2194 processed.
# Row 2195 processed.
# Row 2196 processed.
# Row 2197 processed.
# Row 2198 processed.
# Row 2199 processed.
# Row 2200 processed.
# Row 2201 processed.
# Row 2202 processed.
# Row 2203 processed.
# Row 2204 processed.
# Row 2205 processed.
# Row 2206 processed.
# Row 2207 processed.
# Row 2208 processed.
# Row 2209 processed.
# Row 2210 processed.
# Row 2211 processed.
# Row 2212 processed.
# Row 2213 processed.
# Row 2214 processed.
# Row 2215 processed.
# Row 2216 processed.
# Row 2217 processed.
# Row 2218 processed.
# Row 2219 processed.
# Row 2220 processed.
# Row 2221 processed.
# Row 2222 processed.
# Row 2223 processed.
# Row 2224 processed.
# Row 2225 processed.
# Row 2226 processed.
# Row 2227 processed.
# Row 2228 processed.
# Row 2229 processed.
# Row 2230 processed.
# Row 2231 processed.
# Row 2232 processed.
# Row 2233 processed.
# Row 2234 processed.
# Row 2235 processed.
# Row 2236 processed.
# Row 2237 processed.
# Row 2238 processed.
# Row 2239 processed.
# Row 2240 processed.
# Row 2241 processed.
# Row 2242 processed.
# Row 2243 processed.
# Row 2244 processed.
# Row 2245 processed.
# Row 2246 processed.
# Row 2247 processed.
# Row 2248 processed.
# Row 2249 processed.
# Row 2250 processed.
# Row 2251 processed.
# Row 2252 processed.
# Row 2253 processed.
# Row 2254 processed.
# Row 2255 processed.
# Row 2256 processed.
# Row 2257 processed.
# Row 2258 processed.
# Row 2259 processed.
# Row 2260 processed.
# Row 2261 processed.
# Row 2262 processed.
# Row 2263 processed.
# Row 2264 processed.
# Row 2265 processed.
# Row 2266 processed.
# Row 2267 processed.
# Row 2268 processed.
# Row 2269 processed.
# Row 2270 processed.
# Row 2271 processed.
# Row 2272 processed.
# Row 2273 processed.
# Row 2274 processed.
# Row 2275 processed.
# Row 2276 processed.
# Row 2277 processed.
# Row 2278 processed.
# Row 2279 processed.
# Row 2280 processed.
# Row 2281 processed.
# Row 2282 processed.
# Row 2283 processed.
# Row 2284 processed.
# Row 2285 processed.
# Row 2286 processed.
# Row 2287 processed.
# Row 2288 processed.
# Row 2289 processed.
# Row 2290 processed.
# Row 2291 processed.
# Row 2292 processed.
# Row 2293 processed.
# Row 2294 processed.
# Row 2295 processed.
# Row 2296 processed.
# Row 2297 processed.
# Row 2298 processed.
# Row 2299 processed.
# Row 2300 processed.
# Row 2301 processed.
# Row 2302 processed.
# Row 2303 processed.
# Row 2304 processed.
# Row 2305 processed.
# Row 2306 processed.
# Row 2307 processed.
# Row 2308 processed.
# Row 2309 processed.
# Row 2310 processed.
# Row 2311 processed.
# Row 2312 processed.
# Row 2313 processed.
# Row 2314 processed.
# Row 2315 processed.
# Row 2316 processed.
# Row 2317 processed.
# Row 2318 processed.
# Row 2319 processed.
# Row 2320 processed.
# Row 2321 processed.
# Row 2322 processed.
# Row 2323 processed.
# Row 2324 processed.
# Row 2325 processed.
# Row 2326 processed.
# Row 2327 processed.
# Row 2328 processed.
# Row 2329 processed.
# Row 2330 processed.
# Row 2331 processed.
# Row 2332 processed.
# Row 2333 processed.
# Row 2334 processed.
# Row 2335 processed.
# Row 2336 processed.
# Row 2337 processed.
# Row 2338 processed.
# Row 2339 processed.
# Row 2340 processed.
# Row 2341 processed.
# Row 2342 processed.
# Row 2343 processed.
# Row 2344 processed.
# Row 2345 processed.
# Row 2346 processed.
# Row 2347 processed.
# Row 2348 processed.
# Row 2349 processed.
# Row 2350 processed.
# Row 2351 processed.
# Row 2352 processed.
# Row 2353 processed.
# Row 2354 processed.
# Row 2355 processed.
# Row 2356 processed.
# Row 2357 processed.
# Row 2358 processed.
# Row 2359 processed.
# Row 2360 processed.
# Row 2361 processed.
# Row 2362 processed.
# Row 2363 processed.
# Row 2364 processed.
# Row 2365 processed.
# Row 2366 processed.
# Row 2367 processed.
# Row 2368 processed.
# Row 2369 processed.
# Row 2370 processed.
# Row 2371 processed.
# Row 2372 processed.
# Row 2373 processed.
# Row 2374 processed.
# Row 2375 processed.
# Row 2376 processed.
# Row 2377 processed.
# Row 2378 processed.
# Row 2379 processed.
# Row 2380 processed.
# Row 2381 processed.
# Row 2382 processed.
# Row 2383 processed.
# Row 2384 processed.
# Row 2385 processed.
# Row 2386 processed.
# Row 2387 processed.
# Row 2388 processed.
# Row 2389 processed.
# Row 2390 processed.
# Row 2391 processed.
# Row 2392 processed.
# Row 2393 processed.
# Row 2394 processed.
# Row 2395 processed.
# Row 2396 processed.
# Row 2397 processed.
# Row 2398 processed.
# Row 2399 processed.
# Row 2400 processed.
# Row 2401 processed.
# Row 2402 processed.
# Row 2403 processed.
# Row 2404 processed.
# Row 2405 processed.
# Row 2406 processed.
# Row 2407 processed.
# Row 2408 processed.
# Row 2409 processed.
# Row 2410 processed.
# Row 2411 processed.
# Row 2412 processed.
# Row 2413 processed.
# Row 2414 processed.
# Row 2415 processed.
# Row 2416 processed.
# Row 2417 processed.
# Row 2418 processed.
# Row 2419 processed.
# Row 2420 processed.
# Row 2421 processed.
# Row 2422 processed.
# Row 2423 processed.
# Row 2424 processed.
# Row 2425 processed.
# Row 2426 processed.
# Row 2427 processed.
# Row 2428 processed.
# Row 2429 processed.
# Row 2430 processed.
# Row 2431 processed.
# Row 2432 processed.
# Row 2433 processed.
# Row 2434 processed.
# Row 2435 processed.
# Row 2436 processed.
# Row 2437 processed.
# Row 2438 processed.
# Row 2439 processed.
# ...
# Row 4059 processed.
# Row 4060 processed.
# Row 4061 processed.
# Row 4062 processed.
# Row 4063 processed.
# Row 4064 processed.
# Row 4065 processed.
# Row 4066 processed.
# Row 4067 processed.
# Row 4068 processed.
# Row 4069 processed.
# Row 4070 processed.
# Row 4071 processed.
# Row 4072 processed.
# Row 4073 processed.
# Row 4074 processed.
# Row 4075 processed.
# Row 4076 processed.
# Row 4077 processed.
# Row 4078 processed.
# Row 4079 processed.
# Row 4080 processed.
# Row 4081 processed.
# Row 4082 processed.
# Row 4083 processed.
# Row 4084 processed.
# Row 4085 processed.
# Row 4086 processed.
# Row 4087 processed.
# Row 4088 processed.
# Row 4089 processed.
# Row 4090 processed.
# Row 4091 processed.
# Row 4092 processed.
# Row 4093 processed.
# Row 4094 processed.
# Row 4095 processed.
# Row 4096 processed.
# Row 4097 processed.
# Row 4098 processed.
# Row 4099 processed.
# Row 4100 processed.
# Row 4101 processed.
# Row 4102 processed.
# Row 4103 processed.
# Row 4104 processed.
# Row 4105 processed.
# Row 4106 processed.
# Row 4107 processed.
# Row 4108 processed.
# Row 4109 processed.
# Row 4110 processed.
# Row 4111 processed.
# Row 4112 processed.
# Row 4113 processed.
# Row 4114 processed.
# Row 4115 processed.
# Row 4116 processed.
# Row 4117 processed.
# Row 4118 processed.
# Row 4119 processed.
# Row 4120 processed.
# Row 4121 processed.
# Row 4122 processed.
# Row 4123 processed.
# Row 4124 processed.
# Row 4125 processed.
# Row 4126 processed.
# Row 4127 processed.
# Row 4128 processed.
# Row 4129 processed.
# Row 4130 processed.
# Row 4131 processed.
# Row 4132 processed.
# Row 4133 processed.
# Row 4134 processed.
# Row 4135 processed.
# Row 4136 processed.
# Row 4137 processed.
# Row 4138 processed.
# Row 4139 processed.
# Row 4140 processed.
# Row 4141 processed.
# Row 4142 processed.
# Row 4143 processed.
# Row 4144 processed.
# Row 4145 processed.
# Row 4146 processed.
# Row 4147 processed.
# Row 4148 processed.
# Row 4149 processed.
# Row 4150 processed.
# Row 4151 processed.
# Row 4152 processed.
# Row 4153 processed.
# Row 4154 processed.
# Row 4155 processed.
# Row 4156 processed.
# Row 4157 processed.
# Row 4158 processed.
# Row 4159 processed.
# Row 4160 processed.
# Row 4161 processed.
# Row 4162 processed.
# Row 4163 processed.
# Row 4164 processed.
# Row 4165 processed.
# Row 4166 processed.
# Row 4167 processed.
# Row 4168 processed.
# Row 4169 processed.
# Row 4170 processed.
# Row 4171 processed.
# Row 4172 processed.
# Row 4173 processed.
# Row 4174 processed.
# Row 4175 processed.
# Row 4176 processed.
# Row 4177 processed.
# Row 4178 processed.
# Row 4179 processed.
# Row 4180 processed.
# Row 4181 processed.
# Row 4182 processed.
# Row 4183 processed.
# Row 4184 processed.
# Row 4185 processed.
# Row 4186 processed.
# Row 4187 processed.
# Row 4188 processed.
# Row 4189 processed.
# Row 4190 processed.
# Row 4191 processed.
# Row 4192 processed.
# Row 4193 processed.
# Row 4194 processed.
# Row 4195 processed.
# Row 4196 processed.
# Row 4197 processed.
# Row 4198 processed.
# Row 4199 processed.
# Row 4200 processed.
# Row 4201 processed.
# Row 4202 processed.
# Row 4203 processed.
# Row 4204 processed.
# Row 4205 processed.
# Row 4206 processed.
# Row 4207 processed.
# Row 4208 processed.
# Row 4209 processed.
# Row 4210 processed.
# Row 4211 processed.
# Row 4212 processed.
# Row 4213 processed.
# Row 4214 processed.
# Row 4215 processed.
# Row 4216 processed.
# Row 4217 processed.
# Row 4218 processed.
# Row 4219 processed.
# Row 4220 processed.
# Row 4221 processed.
# Row 4222 processed.
# Row 4223 processed.
# Row 4224 processed.
# Row 4225 processed.
# Row 4226 processed.
# Row 4227 processed.
# Row 4228 processed.
# Row 4229 processed.
# Row 4230 processed.
# Row 4231 processed.
# Row 4232 processed.
# Row 4233 processed.
# Row 4234 processed.
# Row 4235 processed.
# Row 4236 processed.
# Row 4237 processed.
# Row 4238 processed.
# Row 4239 processed.
# Row 4240 processed.
# Row 4241 processed.
# Row 4242 processed.
# Row 4243 processed.
# Row 4244 processed.
# Row 4245 processed.
# Row 4246 processed.
# Row 4247 processed.
# Row 4248 processed.
# Row 4249 processed.
# Row 4250 processed.
# Row 4251 processed.
# Row 4252 processed.
# Row 4253 processed.
# Row 4254 processed.
# Row 4255 processed.
# Row 4256 processed.
# Row 4257 processed.
# Row 4258 processed.
# Row 4259 processed.
# Row 4260 processed.
# Row 4261 processed.
# Row 4262 processed.
# Row 4263 processed.
# Row 4264 processed.
# Row 4265 processed.
# Row 4266 processed.
# Row 4267 processed.
# Row 4268 processed.
# Row 4269 processed.
# Row 4270 processed.
# Row 4271 processed.
# Row 4272 processed.
# Row 4273 processed.
# Row 4274 processed.
# Row 4275 processed.
# Row 4276 processed.
# Row 4277 processed.
# Row 4278 processed.
# Row 4279 processed.
# Row 4280 processed.
# Row 4281 processed.
# Row 4282 processed.
# Row 4283 processed.
# Row 4284 processed.
# Row 4285 processed.
# Row 4286 processed.
# Row 4287 processed.
# Row 4288 processed.
# Row 4289 processed.
# Row 4290 processed.
# Row 4291 processed.
# Row 4292 processed.
# Row 4293 processed.
# Row 4294 processed.
# Row 4295 processed.
# Row 4296 processed.
# Row 4297 processed.
# Row 4298 processed.
# Row 4299 processed.
# Row 4300 processed.
# Row 4301 processed.
# Row 4302 processed.
# Row 4303 processed.
# Row 4304 processed.
# Row 4305 processed.
# Row 4306 processed.
# Row 4307 processed.
# Row 4308 processed.
# Row 4309 processed.
# Row 4310 processed.
# Row 4311 processed.
# Row 4312 processed.
# Row 4313 processed.
# Row 4314 processed.
# Row 4315 processed.
# Row 4316 processed.
# Row 4317 processed.
# Row 4318 processed.
# Row 4319 processed.
# Row 4320 processed.
# Row 4321 processed.
# Row 4322 processed.
# Row 4323 processed.
# Row 4324 processed.
# Row 4325 processed.
# Row 4326 processed.
# Row 4327 processed.
# Row 4328 processed.
# Row 4329 processed.
# Row 4330 processed.
# Row 4331 processed.
# Row 4332 processed.
# Row 4333 processed.
# Row 4334 processed.
# Row 4335 processed.
# Row 4336 processed.
# Row 4337 processed.
# Row 4338 processed.
# Row 4339 processed.
# Row 4340 processed.
# Row 4341 processed.
# Row 4342 processed.
# Row 4343 processed.
# Row 4344 processed.
# Row 4345 processed.
# Row 4346 processed.
# Row 4347 processed.
# Row 4348 processed.
# Row 4349 processed.
# Row 4350 processed.
# Row 4351 processed.
# Row 4352 processed.
# Row 4353 processed.
# Row 4354 processed.
# Row 4355 processed.
# Row 4356 processed.
# Row 4357 processed.
# Row 4358 processed.
# Row 4359 processed.
# Row 4360 processed.
# Row 4361 processed.
# Row 4362 processed.
# Row 4363 processed.
# Row 4364 processed.
# Row 4365 processed.
# Row 4366 processed.
# Row 4367 processed.
# Row 4368 processed.
# Row 4369 processed.
# Row 4370 processed.
# Row 4371 processed.
# Row 4372 processed.
# Row 4373 processed.
# Row 4374 processed.
# Row 4375 processed.
# Row 4376 processed.
# Row 4377 processed.
# Row 4378 processed.
# Row 4379 processed.
# Row 4380 processed.
# Row 4381 processed.
# Row 4382 processed.
# Row 4383 processed.
# Row 4384 processed.
# Row 4385 processed.
# Row 4386 processed.
# Row 4387 processed.
# Row 4388 processed.
# Row 4389 processed.
# Row 4390 processed.
# Row 4391 processed.
# Row 4392 processed.
# Row 4393 processed.
# Row 4394 processed.
# Row 4395 processed.
# Row 4396 processed.
# Row 4397 processed.
# Row 4398 processed.
# Row 4399 processed.
# Row 4400 processed.
# Row 4401 processed.
# Row 4402 processed.
# Row 4403 processed.
# Row 4404 processed.
# Row 4405 processed.
# Row 4406 processed.
# Row 4407 processed.
# Row 4408 processed.
# Row 4409 processed.
# Row 4410 processed.
# Row 4411 processed.
# Row 4412 processed.
# Row 4413 processed.
# Row 4414 processed.
# Row 4415 processed.
# Row 4416 processed.
# Row 4417 processed.
# Row 4418 processed.
# Row 4419 processed.
# Row 4420 processed.
# Row 4421 processed.
# Row 4422 processed.
# Row 4423 processed.
# Row 4424 processed.
# Row 4425 processed.
# Row 4426 processed.
# Row 4427 processed.
# Row 4428 processed.
# Row 4429 processed.
# Row 4430 processed.
# Row 4431 processed.
# Row 4432 processed.
# Row 4433 processed.
# Row 4434 processed.
# Row 4435 processed.
# Row 4436 processed.
# Row 4437 processed.
# Row 4438 processed.
# Row 4439 processed.
# Row 4440 processed.
# Row 4441 processed.
# Row 4442 processed.
# Row 4443 processed.
# Row 4444 processed.
# Row 4445 processed.
# Row 4446 processed.
# Row 4447 processed.
# Row 4448 processed.
# Row 4449 processed.
# Row 4450 processed.
# Row 4451 processed.
# Row 4452 processed.
# Row 4453 processed.
# Row 4454 processed.
# Row 4455 processed.
# Row 4456 processed.
# Row 4457 processed.
# Row 4458 processed.
# Row 4459 processed.
# Row 4460 processed.
# Row 4461 processed.
# Row 4462 processed.
# Row 4463 processed.
# Row 4464 processed.
# Row 4465 processed.
# Row 4466 processed.
# Row 4467 processed.
# Row 4468 processed.
# Row 4469 processed.
# Row 4470 processed.
# Row 4471 processed.
# Row 4472 processed.
# Row 4473 processed.
# Row 4474 processed.
# Row 4475 processed.
# Row 4476 processed.
# Row 4477 processed.
# Row 4478 processed.
# Row 4479 processed.
# Row 4480 processed.
# Row 4481 processed.
# Row 4482 processed.
# Row 4483 processed.
# Row 4484 processed.
# Row 4485 processed.
# Row 4486 processed.
# Row 4487 processed.
# Row 4488 processed.
# Row 4489 processed.
# Row 4490 processed.
# Row 4491 processed.
# Row 4492 processed.
# Row 4493 processed.
# Row 4494 processed.
# Row 4495 processed.
# Row 4496 processed.
# Row 4497 processed.
# Row 4498 processed.
# Row 4499 processed.
# Row 4500 processed.
# Row 4501 processed.
# Row 4502 processed.
# Row 4503 processed.
# Row 4504 processed.
# Row 4505 processed.
# Row 4506 processed.
# Row 4507 processed.
# Row 4508 processed.
# Row 4509 processed.
# Row 4510 processed.
# Row 4511 processed.
# Row 4512 processed.
# Row 4513 processed.
# Row 4514 processed.
# Row 4515 processed.
# Row 4516 processed.
# Row 4517 processed.
# Row 4518 processed.
# Row 4519 processed.
# Row 4520 processed.
# Row 4521 processed.
# Row 4522 processed.
# Row 4523 processed.
# Row 4524 processed.
# Row 4525 processed.
# Row 4526 processed.
# Row 4527 processed.
# Row 4528 processed.
# Row 4529 processed.
# Row 4530 processed.
# Row 4531 processed.
# Row 4532 processed.
# Row 4533 processed.
# Row 4534 processed.
# Row 4535 processed.
# Row 4536 processed.
# Row 4537 processed.
# Row 4538 processed.
# Row 4539 processed.
# Row 4540 processed.
# Row 4541 processed.
# Row 4542 processed.
# Row 4543 processed.
# Row 4544 processed.
# Row 4545 processed.
# Row 4546 processed.
# Row 4547 processed.
# Row 4548 processed.
# Row 4549 processed.
# Row 4550 processed.
# Row 4551 processed.
# Row 4552 processed.
# Row 4553 processed.
# Row 4554 processed.
# Row 4555 processed.
# Row 4556 processed.
# Row 4557 processed.
# Row 4558 processed.
# Row 4559 processed.
# Row 4560 processed.
# Row 4561 processed.
# Row 4562 processed.
# Row 4563 processed.
# Row 4564 processed.
# Row 4565 processed.
# Row 4566 processed.
# Row 4567 processed.
# Row 4568 processed.
# Row 4569 processed.
# Row 4570 processed.
# Row 4571 processed.
# Row 4572 processed.
# Row 4573 processed.
# Row 4574 processed.
# Row 4575 processed.
# Row 4576 processed.
# Row 4577 processed.
# Row 4578 processed.
# Row 4579 processed.
# Row 4580 processed.
# Row 4581 processed.
# Row 4582 processed.
# Row 4583 processed.
# Row 4584 processed.
# Row 4585 processed.
# Row 4586 processed.
# Row 4587 processed.
# Row 4588 processed.
# Row 4589 processed.
# Row 4590 processed.
# Row 4591 processed.
# Row 4592 processed.
# Row 4593 processed.
# Row 4594 processed.
# Row 4595 processed.
# Row 4596 processed.
# Row 4597 processed.
# Row 4598 processed.
# Row 4599 processed.
# Row 4600 processed.
# Row 4601 processed.
# Row 4602 processed.
# Row 4603 processed.
# Row 4604 processed.
# Row 4605 processed.
# Row 4606 processed.
# Row 4607 processed.
# Row 4608 processed.
# Row 4609 processed.
# Row 4610 processed.
# Row 4611 processed.
# Row 4612 processed.
# Row 4613 processed.
# Row 4614 processed.
# Row 4615 processed.
# Row 4616 processed.
# Row 4617 processed.
# Row 4618 processed.
# Row 4619 processed.
# Row 4620 processed.
# Row 4621 processed.
# Row 4622 processed.
# Row 4623 processed.
# Row 4624 processed.
# Row 4625 processed.
# Row 4626 processed.
# Row 4627 processed.
# Row 4628 processed.
# Row 4629 processed.
# Row 4630 processed.
# Row 4631 processed.
# Row 4632 processed.
# Row 4633 processed.
# Row 4634 processed.
# Row 4635 processed.
# Row 4636 processed.
# Row 4637 processed.
# Row 4638 processed.
# Row 4639 processed.
# Row 4640 processed.
# Row 4641 processed.
# Row 4642 processed.
# Row 4643 processed.
# Row 4644 processed.
# Row 4645 processed.
# Row 4646 processed.
# Row 4647 processed.
# Row 4648 processed.
# Row 4649 processed.
# Row 4650 processed.
# Row 4651 processed.
# Row 4652 processed.
# Row 4653 processed.
# Row 4654 processed.
# Row 4655 processed.
# Row 4656 processed.
# Row 4657 processed.
# Row 4658 processed.
# Row 4659 processed.
# Row 4660 processed.
# Row 4661 processed.
# Row 4662 processed.
# Row 4663 processed.
# Row 4664 processed.
# Row 4665 processed.
# Row 4666 processed.
# Row 4667 processed.
# Row 4668 processed.
# Row 4669 processed.
# Row 4670 processed.
# Row 4671 processed.
# Row 4672 processed.
# Row 4673 processed.
# Row 4674 processed.
# Row 4675 processed.
# Row 4676 processed.
# Row 4677 processed.
# Row 4678 processed.
# Row 4679 processed.
# Row 4680 processed.
# Row 4681 processed.
# Row 4682 processed.
# Row 4683 processed.
# Row 4684 processed.
# Row 4685 processed.
# Row 4686 processed.
# Row 4687 processed.
# Row 4688 processed.
# Row 4689 processed.
# Row 4690 processed.
# Row 4691 processed.
# Row 4692 processed.
# Row 4693 processed.
# Row 4694 processed.
# Row 4695 processed.
# Row 4696 processed.
# Row 4697 processed.
# Row 4698 processed.
# Row 4699 processed.
# Row 4700 processed.
# Row 4701 processed.
# Row 4702 processed.
# Row 4703 processed.
# Row 4704 processed.
# Row 4705 processed.
# Row 4706 processed.
# Row 4707 processed.
# Row 4708 processed.
# Row 4709 processed.
# Row 4710 processed.
# Row 4711 processed.
# Row 4712 processed.
# Row 4713 processed.
# Row 4714 processed.
# Row 4715 processed.
# Row 4716 processed.
# Row 4717 processed.
# Row 4718 processed.
# Row 4719 processed.
# Row 4720 processed.
# Row 4721 processed.
# Row 4722 processed.
# Row 4723 processed.
# Row 4724 processed.
# Row 4725 processed.
# Row 4726 processed.
# Row 4727 processed.
# Row 4728 processed.
# Row 4729 processed.
# Row 4730 processed.
# Row 4731 processed.
# Row 4732 processed.
# Row 4733 processed.
# Row 4734 processed.
# Row 4735 processed.
# Row 4736 processed.
# Row 4737 processed.
# Row 4738 processed.
# Row 4739 processed.
# Row 4740 processed.
# Row 4741 processed.
# Row 4742 processed.
# Row 4743 processed.
# Row 4744 processed.
# Row 4745 processed.
# Row 4746 processed.
# Row 4747 processed.
# Row 4748 processed.
# Row 4749 processed.
# Row 4750 processed.
# Row 4751 processed.
# Row 4752 processed.
# Row 4753 processed.
# Row 4754 processed.
# Row 4755 processed.
# Row 4756 processed.
# Row 4757 processed.
# Row 4758 processed.
# Row 4759 processed.
# Row 4760 processed.
# Row 4761 processed.
# Row 4762 processed.
# Row 4763 processed.
# Row 4764 processed.
# Row 4765 processed.
# Row 4766 processed.
# Row 4767 processed.
# Row 4768 processed.
# Row 4769 processed.
# Row 4770 processed.
# Row 4771 processed.
# Row 4772 processed.
# Row 4773 processed.
# Row 4774 processed.
# Row 4775 processed.
# Row 4776 processed.
# Row 4777 processed.
# Row 4778 processed.
# Row 4779 processed.
# Row 4780 processed.
# Row 4781 processed.
# Row 4782 processed.
# Row 4783 processed.
# Row 4784 processed.
# Row 4785 processed.
# Row 4786 processed.
# Row 4787 processed.
# Row 4788 processed.
# Row 4789 processed.
# Row 4790 processed.
# Row 4791 processed.
# Row 4792 processed.
# Row 4793 processed.
# Row 4794 processed.
# Row 4795 processed.
# Row 4796 processed.
# Row 4797 processed.
# Row 4798 processed.
# Row 4799 processed.
# Row 4800 processed.
# Row 4801 processed.
# Row 4802 processed.
# Row 4803 processed.
# Row 4804 processed.
# Row 4805 processed.
# Row 4806 processed.
# Row 4807 processed.
# Row 4808 processed.
# Row 4809 processed.
# Row 4810 processed.
# Row 4811 processed.
# Row 4812 processed.
# Row 4813 processed.
# Row 4814 processed.
# Row 4815 processed.
# Row 4816 processed.
# Row 4817 processed.
# Row 4818 processed.
# Row 4819 processed.
# Row 4820 processed.
# Row 4821 processed.
# Row 4822 processed.
# Row 4823 processed.
# Row 4824 processed.
# Row 4825 processed.
# Row 4826 processed.
# Row 4827 processed.
# Row 4828 processed.
# Row 4829 processed.
# Row 4830 processed.
# Row 4831 processed.
# Row 4832 processed.
# Row 4833 processed.
# Row 4834 processed.
# Row 4835 processed.
# Row 4836 processed.
# Row 4837 processed.
# Row 4838 processed.
# Row 4839 processed.
# Row 4840 processed.
# Row 4841 processed.
# Row 4842 processed.
# Row 4843 processed.
# Row 4844 processed.
# Row 4845 processed.
# Row 4846 processed.
# Row 4847 processed.
# Row 4848 processed.
# Row 4849 processed.
# Row 4850 processed.
# Row 4851 processed.
# Row 4852 processed.
# Row 4853 processed.
# Row 4854 processed.
# Row 4855 processed.
# Row 4856 processed.
# Row 4857 processed.
# Row 4858 processed.

# %%
df.head(15)
# Out:
#     event_number  booking_number start_date                event_desc  \
# 0          11259       100718554 2026-04-26  TCS London Marathon 2026
# 1          11259       100718557 2026-04-26  TCS London Marathon 2026
# 2          11259       100718558 2026-04-26  TCS London Marathon 2026
# 3          11259       100718559 2026-04-26  TCS London Marathon 2026
# 4          11259       100718560 2026-04-26  TCS London Marathon 2026
# 5          11259       100718561 2026-04-26  TCS London Marathon 2026
# 6          11259       100718562 2026-04-26  TCS London Marathon 2026
# 7          11259       100718564 2026-04-26  TCS London Marathon 2026
# 8          11259       100718565 2026-04-26  TCS London Marathon 2026
# 9          11259       100718566 2026-04-26  TCS London Marathon 2026
# 10         11259       100718567 2026-04-26  TCS London Marathon 2026
# 11         11259       100718568 2026-04-26  TCS London Marathon 2026
# 12         11259       100718569 2026-04-26  TCS London Marathon 2026
# 13         11259       100718571 2026-04-26  TCS London Marathon 2026
# 14         11259       100718572 2026-04-26  TCS London Marathon 2026
#
#                       option_desc       employee_details_job_title  \
# 0   Guaranteed Place - Interested
# 1   Guaranteed Place - Interested             E-Commerce Executive
# 2   Guaranteed Place - Interested                      Hairdresser
# 3   Guaranteed Place - Interested               Head of Operations
# 4   Guaranteed Place - Interested                 Project Director
# 5   Guaranteed Place - Interested              Railway maintenance
# 6   Guaranteed Place - Interested                            trade
# 7   Guaranteed Place - Interested                Head of Marketing
# 8   Guaranteed Place - Interested                   CYP Counsellor
# 9   Guaranteed Place - Interested                           Barber
# 10    Guaranteed Place - Rejected                      Taxi driver
# 11  Guaranteed Place - Interested                    SELF EMPLOYED
# 12  Guaranteed Place - Interested  Assistant Management Accountant
# 13  Guaranteed Place - Interested                   Senior Analyst
# 14  Guaranteed Place - Interested                             chef
#
#          employee_details_employer recruitment_source_drop_down  \
# 0                                         Other, please specify
# 1            Computer Recyclers UK        Other, please specify
# 2                    Self employed        Other, please specify
# 3         MSI Reproductive Choices        Other, please specify
# 4                                         Other, please specify
# 5                    Self employed        Other, please specify
# 6                   SCM Sp. z o.o.        Other, please specify
# 7                      Score Group        Other, please specify
# 8   Wokingham Counselling Services        Other, please specify
# 9                                                 Word of mouth
# 10                      London tfl        Other, please specify
# 11                  MY OWN COMPANY                Word of mouth
# 12                    Alpha Living        Other, please specify
# 13               Complete Strategy        Other, please specify
# 14           the three horse shoes        Other, please specify
#
#                          recruitment_source_free_text in_mem  ...  \
# 0                                                         No  ...
# 1                                                        Yes  ...
# 2                                                        Yes  ...
# 3   I've always said I would run a marathon before...    Yes  ...
# 4                                                         No  ...
# 5                                                        Yes  ...
# 6                                                         No  ...
# 7                                                         No  ...
# 8                                                        Yes  ...
# 9                                                        Yes  ...
# 10                                                        No  ...
# 11                                                        No  ...
# 12                                                        No  ...
# 13                                                        No  ...
# 14                                                        No  ...
#
#    special_plans_and/or_fancy_dress_drop_down  \
# 0                                          No
# 1                                          No
# 2                                          No
# 3                                          No
# 4                                          No
# 5
# 6                                          No
# 7                                          No
# 8
# 9                                          No
# 10                                         No
# 11                                         No
# 12                                         No
# 13                                         No
# 14                                         No
#
#          special_plans_and/or_fancy_dress_drop_down.1 terms_and_conditions  \
# 0                                                         Yes: General T&C
# 1                                                         Yes: General T&C
# 2                                                         Yes: General T&C
# 3                                                         Yes: General T&C
# 4                                                         Yes: General T&C
# 5   I’m not 100% sure what I will do yet but I wan...     Yes: General T&C
# 6                                                         Yes: General T&C
# 7                                                         Yes: General T&C
# 8   I will dress in yellow, perhaps as a daffodil....     Yes: General T&C
# 9                                                         Yes: General T&C
# 10                                                        Yes: General T&C
# 11                                                        Yes: General T&C
# 12                                                        Yes: General T&C
# 13                                                        Yes: General T&C
# 14                                                        Yes: General T&C
#
#                            ext_event_ref        id emotion purpose commitment  \
# 0   a7de13b6-23d5-405c-981a-d46e03ef87a2  581Q6081     0.5     0.5        1.5
# 1   51e07904-dcbb-4cf1-8a11-946152218433  9N989Q6A       5       5          5
# 2   b1a28e5b-992b-4aed-b066-77f86af4cb18  BQ78T590     5.0     5.0          5
# 3   bd57115f-e477-414c-808c-6277aff9e38e  7P557RQZ     4.8       5          5
# 4   ecc838d4-2b5c-4beb-9cda-11c6090134fd  3371627M     4.7     4.7        4.8
# 5   85ce6e99-eaaf-4fed-b422-181281178ebb  L2109736     5.0     5.0          5
# 6   bef0a72d-7f47-4c80-8158-747771f91998  59D3KQM5     3.8     4.2        4.5
# 7   a19af117-c804-4ff7-892d-57f8bde85097  16MAOA6X     4.8       5        4.8
# 8   7dffe007-e324-4ce7-a654-af48aedac1c2  M3THI5D2       5       5          5
# 9   94e4a3cd-f6cf-424c-b576-12e1470d0f54  WDYBH1J0     4.7     4.8        4.8
# 10                                175614  M05E8057     3.5     3.5        3.5
# 11  401da329-4f48-40fb-8e39-713030f20bf3  688SN331     1.5     1.5        2.0
# 12  c8e22606-e903-4e11-8f55-44d9c10a097f  E0NFGHWZ     3.8     4.8        4.7
# 13  b4b99b58-3c96-4079-99a3-55096dbd0ca8  6RX43S23     3.8     4.8        4.7
# 14  f748f66d-5c8d-4bda-aa4e-9ed384be4d2d  D6W1937W     2.0     2.5        1.5
#
#    fundraising Final_score
# 0          0.5         3.5
# 1          4.5        22.5
# 2          1.5        22.5
# 3          3.0        22.3
# 4          3.5        21.2
# 5          4.0        26.0
# 6            0        13.5
# 7          4.8        22.9
# 8          4.5        28.0
# 9          4.8        25.6
# 10         1.5        15.0
# 11         1.5         6.5
# 12         4.5        18.3
# 13           5        21.3
# 14         1.0         8.5
#
# [15 rows x 34 columns]
